# %% [markdown]
# # TR-RB simulation

# %%
# ~~~
# This file is part of the paper:
#
#           "An adaptive projected Newton non-conforming dual approach
#         for trust-region reduced basis approximation of PDE-constrained
#                           parameter optimization"
#
#   https://github.com/TiKeil/Proj-Newton-NCD-corrected-TR-RB-for-pde-opt
#
# Copyright 2019-2020 all developers. All rights reserved.
# License: Licensed as BSD 2-Clause License (http://opensource.org/licenses/BSD-2-Clause)
# Authors:
#   Luca Mechelli (2019 - 2020)
#   Tim Keil      (2019 - 2020)
# ~~~

# %% [markdown]
# # Preparations

# %% [markdown]
# ## details

# %% [markdown]
# In this notebook we discretize the following problem:
# Find $u_{\mu}$ solving the following parametrized constrained equation
#
# \begin{align*}
# 	-  \nabla \cdot \left( \kappa_{\mu}  \nabla u_{\mu} \right) &= f_{\mu} &&\text{in } \Omega, \\
# 	q ( \kappa_{\mu}  \nabla u_{\mu} \cdot n) &= (u_{\text{out}} - u_{\mu}) &&\text{on } \partial \Omega.
# \end{align*}

# %% [markdown]
# For the definition of $\kappa_{\mu}$ and $f_{\mu}$ in the computational domain $\Omega$, we use the `BitmapFunction` from PyMOR. This function uses the Python Imaging Library (PIL) in order to convert a .png grayscale picture to a data function on our domain.
# Walls, windows and doors are stored in seperated .png to enable a affine decomposition of each part of the picture. Furthermore, we are considering a heater at each window. The numbering of the components for $\kappa_{\mu}$ can be seen in the following picture
# ![EXC_notebook_data/EXC_MM_with_numbers.png](../../EXC_notebook_data/Domain_of_interestin_Omega.png)
#
# Here, numbers with | are walls, numbers with _ are doors and numbers with dots are windows
#
# The heaters are numbered in the following way:
# ![EXC_notebook_data/EXC_MM_with_numbers_heat.png](../../EXC_notebook_data/EXC_MM_with_numbers_heat.png)

# %% [markdown]
# For our pde constrained model, we need to define a cost functional. In a general quadratic model, we have
#
# \begin{align}
# \mathcal{J}(u, \mu) := \Theta(\mu) + j_\mu(u) + k_\mu(u, u),
# \end{align}
#
# For this code, we restrict ourselves to the following definition
# \begin{align}
# \mathcal{J}(v, \mu) = \frac{\sigma_d}{2} \int_{D}^{} (v - u^{\text{d}})^2 + \frac{1}{2} \sum^{M}_{i=1} \sigma_i \mu_i^2,
# \end{align}
# which means
#
# \begin{align}
# \Theta(\mu) &= \frac{1}{2} \sum^{M}_{i=1} \sigma_i \mu_i^2 + \frac{\sigma_d}{2} \int_{D}^{} u^{\text{d}} u^{\text{d}}\\
# j_{\mu}(u) & = -\sigma_d \int_{D}^{} u^{\text{d}}u \\
# k_{\mu}(u,u) &= \frac{\sigma_d}{2} \int_{D}^{} u^2
# \end{align}
#
# The following code implements this particular case.

# %% [markdown]
# ## prepare cells

# %%
import numpy as np

from matplotlib import pyplot as plt

from pymor.basic import *
set_log_levels({'pymor': 'WARN'})

# %%
from pymor.core.logger import set_log_levels, getLogger
set_log_levels({'pymor': 'ERROR',
                'distributed_adaptive_discretizations': 'DEBUG',
                'notebook': 'INFO'})
logger = getLogger('notebook.notebook')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12.0, 8.0)
mpl.rcParams['font.size'] = 12
mpl.rcParams['savefig.dpi'] = 300

data_path = '../../../EXC_data'
# domain of interest
bounding_box = [[0,0],[2,1]]
domain_of_interest = BitmapFunction('{}/Domain_of_interest.png'.format(data_path), range=[1,0], bounding_box=bounding_box)

# %% [markdown]
# ## problem definition and tolerances

# %%
from pdeopt.problems import EXC_problem, set_input_dict
from pdeopt.discretizer import discretize_quadratic_pdeopt_stationary_cg

parametric_quantities = {'walls': [1,4,9], 'windows': [], 'doors': [6,7], 'heaters': [1,3,5,6,7,8,9]}
inactive_quantities = {'removed_walls': [], 'open_windows': [], 'open_doors': [1,2,3,4,5,10], 'active_heaters': []}
summed_quantities = {'walls': [[1,2,3,7,8],[4,5,6]], 'windows': [], 'doors': [], 'heaters': [[1,2],[3,4],[9,10,11,12]]}

coefficient_expressions = None

parameters_in_q = True
input_dict = set_input_dict(parametric_quantities, inactive_quantities, coefficient_expressions, summed_quantities, parameters_in_q,
                            ac=0.5, owc=[0.025,0.1], iwc= [0.025,0.1], idc=[0.05,0.2], wc=[0.0005], ht=[0,100],
                                    owc_c=0.001,  iwc_c= 0.025,     idc_c=0.01,  wc_c=0.05,  ht_c=80)


parameter_scaling = False
u_out = 5

problem, parameter_scales = EXC_problem(input_dict, summed_quantities, outside_temperature=u_out, #, q_inverse=0.0001
                                        data_path = data_path,parameters_in_q=parameters_in_q, 
                                        parameter_scaling=parameter_scaling,
                                        coefficient_expressions=coefficient_expressions)

u_d = 18 

mu_d = problem.parameter_space.sample_randomly(1, seed=10)[0]
mu_d = None

sigma_d = 100
weights = {'walls': 0.1, 'doors': 1, 'heaters': [0.002,0.002,0.0005,0.0005,0.0005,0.0005,0.004], 'windows': 1, 'state': sigma_d}

diameter = np.sqrt(2)/200.
opt_fom, data, mu_bar = discretize_quadratic_pdeopt_stationary_cg(problem, diameter, weights, parameter_scales, 
                                                          domain_of_interest, desired_temperature=u_d, 
                                                          mu_for_u_d=mu_d, mu_for_tikhonov=mu_d,
                                                          parameters_in_q=parameters_in_q, product='fixed_energy')
# Out:
# I am using the NCD corrected functional!!
# my product is fixed_energy
# mu_bar is: {doors: [0.1, 0.1], heaters: [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0], walls: [0.049999999999999996, 0.049999999999999996, 0.049999999999999996]}

# %%
print('Information on the grid:')
print(data['grid'])

seed = 8                   # random seed for the starting value
radius = 0.1               # TR radius 
FOC_tolerance = 1e-7       # tau_FOC
sub_tolerance = 1e-8       # tau_sub
safety_tol = 1e-16         # Safeguard, to avoid running the optimizer for really small difference in digits
max_it = 60                # Maximum number of iteration for the TR algorithm
max_it_sub = 400           # Maximum number of iteration for the TR optimization subproblem
max_it_SH = 800            # Maximum number of iteration for the TR Steihaug method
max_it_arm = 50            # Maximum number of iteration for the Armijo rule
init_step_armijo = 0.5     # Initial step for the Armijo rule
armijo_alpha = 1e-4        # kappa_arm
beta = 0.95                # beta_2
epsilon_i = 1e-8           # Treshold for the epsilon active set (Kelley '99)
iterative_solver = 'CG'    # chosen iterative solver

# parameter control
control_mu = False         # enable post processing for the optimal parameter estimation

# optional enrichment
tau_g = FOC_tolerance/sub_tolerance
tau_grad = 0.01
beta_3 = 1./2
minimum_radius = 1e-6
maximum_radius = 1e16

# some implementational variables
Qian_Grepl_subproblem = True
reductor_type = 'simple_coercive'
# Out:
# Information on the grid:
# Rect-Grid on domain [0,2] x [0,1]
# x0-intervals: 400, x1-intervals: 200
# faces: 80000, edges: 160600, vertices: 80601

# %%
# starting with 
parameter_space = problem.parameter_space
mu = parameter_space.sample_randomly(1, seed=seed)[0]

# %% [markdown]
# ### What methods do you want to test ?

# %%
optimization_methods = [
    # FOM Method
    'SH',   # Steihaug Version 4
    # Newton 
        # NCD-corrected
         'Method_4', # TR-RB (a)
         'Method_4_optional',
         'Method_5', # TR-RB (c)
         'Method_5_optional',
        # Aggregated
#          'Method_6', # TR-RB (b) 
#          'Method_7', # TR-RB (d)
    # BFGS
        # NCD-corrected from KMSOV'20
         'Method_8', # TR-RB
    # Qian Grepl method from QGVW'17
#          'Method_9'
]

#optimization_methods = ['All']

# %% [markdown]
# ## Visualizations

# %% [markdown]
# Visualize diffusion and rhs

# %%
from pymor.discretizers.builtin.cg import InterpolationOperator

vis_mu = mu.copy()
diff = InterpolationOperator(data['grid'], problem.diffusion).as_vector(vis_mu)
rhs = InterpolationOperator(data['grid'], problem.rhs).as_vector(vis_mu)
doI = InterpolationOperator(data['grid'], domain_of_interest).as_vector(vis_mu)

opt_fom.visualize(diff)
# Out:
# Output()

# %%
opt_fom.visualize(rhs)
# Out:
# Output()

# %%
opt_fom.visualize(doI)
# Out:
# Output()

# %% [markdown]
# We can easily solve the primal and dual equations by calling

# %%
u = opt_fom.solve(mu)
p = opt_fom.solve_dual(mu)

opt_fom.visualize(u)
# Out:
# Output()

# %%
opt_fom.visualize(p)
# Out:
# Output()

# %% [markdown]
# # Full Order Optimization

# %%
parameters = opt_fom.parameters
if mu_d is not None:
    mu_opt = mu_d
else:
    #use result from previous FOM run
    mu_opt = parameters.parse(np.array([5.000000000000e-02,  5.000000000000e-02,  2.238254711947e+01,
  2.339650455721e+01,  4.870348426512e+01,  4.937422778852e+01,
  5.236272251326e+01,  5.411556305764e+01,  2.352380079299e+01,
  2.500000000000e-02,  2.500000000000e-02,  2.500000000000e-02]))
    
mu_opt_as_array = mu_opt.to_numpy()
J_opt = opt_fom.output_functional_hat(mu_opt)
print('Optimal parameter: ', mu_opt_as_array)
print('Optimal J: ', J_opt)

print()
print('Starting parameter: ', mu.to_numpy())
J_start = opt_fom.output_functional_hat(mu)
print('Starting J: ', J_start)
# Out:
# Optimal parameter:  [5.00000000e-02 5.00000000e-02 2.23825471e+01 2.33965046e+01
#  4.87034843e+01 4.93742278e+01 5.23627225e+01 5.41155631e+01
#  2.35238008e+01 2.50000000e-02 2.50000000e-02 2.50000000e-02]
# Optimal J:  5.813965062384796
#
# Starting parameter:  [1.81014410e-01 1.95281099e-01 8.69194540e+01 5.30855692e+01
#  2.32728328e+01 1.13988043e+00 4.30468818e+01 4.02351360e+01
#  5.22674671e+01 6.08793847e-02 6.66517355e-02 6.57539513e-02]
# Starting J:  232.52364610709583

# %%
print(mu_opt.parameters)
# Out:
# {doors: 2, heaters: 7, walls: 3}

# %% [markdown]
# # TR Steihaug

# %%
from pdeopt.TR import TR_Steihaug
from pdeopt.tools import compute_errors

TR_parameters = {'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'max_iterations_subproblem': max_it_sub,
                 'max_iterations': max_it_SH,
                 'starting_parameter': mu, 
                 'epsilon_i': epsilon_i,
                 'max_iterations_armijo': max_it_arm, 'initial_step_armijo': init_step_armijo,
                 'armijo_alpha': armijo_alpha,
                 'full_order_model': True,
                 'iterative_solver': iterative_solver}

if 'SH'  in optimization_methods or 'All' in optimization_methods:
    mus_SH, times_SH, Js_SH, FOC_SH = TR_Steihaug(opt_fom, problem.parameter_space, TR_parameters)
    times_full_SH, J_error_SH, mu_error_SH, FOC = compute_errors(opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, 
                                                       mus_SH, Js_SH, times_SH, 0, FOC_SH)
# Out:
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.2
# k: 1 - Cost Functional: 224.47068666303403 - mu: {doors: [0.07863166949846587, 0.19986706173882166], heaters: [86.719454021392, 52.88556915555989, 23.07283279772907, 0.9398804277429896, 42.84688182924905, 40.03513600373648, 52.06746713525696], walls: [0.02601077421202439, 0.026173389692603063, 0.02614809781130422]}
# First order critical condition: 11.79587739393538
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.4
# k: 2 - Cost Functional: 213.44041166716033 - mu: {doors: [0.05163329967310577, 0.19999241650863087], heaters: [86.31945402139199, 52.485569155559894, 22.672832797729072, 0.5398804277429896, 42.44688182924905, 39.635136003736484, 51.66746713525696], walls: [0.02505765982979692, 0.025066936264455587, 0.025065493483710306]}
# First order critical condition: 11.463549921126097
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.8
# k: 3 - Cost Functional: 193.08645107695065 - mu: {doors: [0.05018836921738315, 0.19999912539238343], heaters: [85.519454021392, 51.6855691555599, 21.87283279772907, 0.0, 41.646881829249054, 38.83513600373649, 50.867467135256966], walls: [0.025006649935215283, 0.02500771979077549, 0.025007553394195414]}
# First order critical condition: 10.863110433379433
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 1.6
# k: 4 - Cost Functional: 157.68090982832746 - mu: {doors: [0.050045126570042314, 0.1999997904750977], heaters: [83.919454021392, 50.085569155559895, 20.27283279772907, 0.0, 40.04688182924905, 37.235136003736486, 49.267467135256965], walls: [0.02500159308814592, 0.025001849387516612, 0.025001809524809585]}
# First order critical condition: 9.75783121195813
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 3.2
# k: 5 - Cost Functional: 98.27523337465027 - mu: {doors: [0.05002232120428449, 0.19999989636154172], heaters: [80.719454021392, 46.88556915555989, 17.07283279772907, 0.0, 36.84688182924905, 34.03513600373648, 46.06746713525696], walls: [0.02500078799797802, 0.02500091477274964, 0.025000895055238958]}
# First order critical condition: 7.547363425406764
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 6.4
# k: 6 - Cost Functional: 25.07979728212331 - mu: {doors: [0.050023612744644355, 0.1999998903648558], heaters: [74.31945402139199, 40.485569155559894, 10.672832797729068, 0.0, 30.446881829249048, 27.63513600373648, 39.66746713525696], walls: [0.025000833592793564, 0.025000967702954985, 0.02500094684455779]}
# First order critical condition: 3.1279010494594828
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 12.8
# k: 7 - Cost Functional: 9.819039665398122 - mu: {doors: [0.05, 0.05000000000000002], heaters: [69.58187158521613, 35.922614460855165, 8.481815432461385, 0.0, 28.001898140888613, 25.114347387527385, 33.17709118913748], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.18160503019116905
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 25.6
# k: 8 - Cost Functional: 8.362538555642686 - mu: {doors: [0.05, 0.05], heaters: [56.781515139864254, 35.29593835496631, 14.498890775361307, 6.928394720166512, 32.75232643784116, 30.345106130212027, 34.04083257812463], walls: [0.03606263588962738, 0.025775011670882107, 0.025]}
# First order critical condition: 0.16636268705530152
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 51.2
# k: 9 - Cost Functional: 6.488974370499136 - mu: {doors: [0.05, 0.05], heaters: [31.166918262734246, 33.07270081946824, 28.645227459740397, 23.304323057207387, 43.62679754704246, 42.365187269191026, 32.72936863590569], walls: [0.06309189186002848, 0.025, 0.027299593615570904]}
# First order critical condition: 0.0863618208715478
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 102.4
# k: 10 - Cost Functional: 5.820916333755349 - mu: {doors: [0.05, 0.05], heaters: [22.570485746974157, 23.543650450444158, 48.43886876470107, 48.93770352274568, 52.07277506398772, 53.80130016092206, 23.45043625518894], walls: [0.025000000000001063, 0.025, 0.02500000000000019]}
# First order critical condition: 0.0671714568154578
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 11 - Cost Functional: 5.814174114387015 - mu: {doors: [0.05, 0.05], heaters: [22.634961931095766, 23.612925175280484, 48.48645703423205, 48.99152014765962, 52.12479369982169, 53.855720200813685, 23.603728169439716], walls: [0.025000000000015312, 0.025, 0.025]}
# First order critical condition: 0.0021869446183920243
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 12 - Cost Functional: 5.8139725757878296 - mu: {doors: [0.05, 0.05], heaters: [22.388429876581085, 23.401193019113652, 48.6947064794831, 49.35952091102972, 52.35312202385525, 54.10514169211047, 23.521760844378885], walls: [0.025000000001222294, 0.025, 0.025]}
# First order critical condition: 0.002208304071671838
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 13 - Cost Functional: 5.813965288747113 - mu: {doors: [0.05, 0.05], heaters: [22.39056096696806, 23.403476539963986, 48.696274460751845, 49.36130302778996, 52.35483541861845, 54.10693478820412, 23.526786180470864], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 7.191500369829725e-05
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 14 - Cost Functional: 5.813965070487711 - mu: {doors: [0.05, 0.05], heaters: [22.382731495142924, 23.39665421830757, 48.70319464940398, 49.37373454141536, 52.3624062816604, 54.11521928106359, 23.5237438686029], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 7.251465527338657e-05
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 15 - Cost Functional: 5.813965062630132 - mu: {doors: [0.05, 0.05], heaters: [22.382801813474686, 23.396729377603183, 48.70324620575457, 49.373793429180175, 52.36246260223886, 54.115278239260974, 23.52390849922242], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.361909185532177e-06
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 16 - Cost Functional: 5.813965062394118 - mu: {doors: [0.05, 0.05], heaters: [22.38255291154345, 23.396509346527814, 48.703474747280985, 49.37421129891497, 52.36271213879463, 54.115551761404454, 23.523799195429223], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.3791962762181547e-06
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 17 - Cost Functional: 5.813965062385478 - mu: {doors: [0.05, 0.05], heaters: [22.382555228590153, 23.396511817409177, 48.70347644037676, 49.37421324178986, 52.36271398739482, 54.11555369651673, 23.523804586471204], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 7.750358550541244e-08
# ***********************************************
#
#
# Stopping criteria fulfilled: FOC condition: 7.750358550541244e-08

# %%
if 'SH' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,J_error_SH, label='SH J')
    plt.legend()

# %%
# compute the error in the target
from pymor.discretizers.builtin.cg import (L2ProductP1, L2ProductQ1, InterpolationOperator)
from pymor.discretizers.builtin.grids.referenceelements import square
from pymor.discretizers.builtin.grids.boundaryinfos import EmptyBoundaryInfo
if data['grid'].reference_element is square:
    L2_OP = L2ProductQ1
else:
    L2_OP = L2ProductP1
if mu_d is None:
    if 'SH' in optimization_methods or 'All' in optimization_methods:
        empty_bi = EmptyBoundaryInfo(data['grid'])
        u_d = InterpolationOperator(data['grid'], ConstantFunction(u_d,2)).as_vector()
        diff= u.to_numpy()-u_d.to_numpy()
        diff_= opt_fom.solution_space.from_numpy(diff)
        Restricted_L2_OP = L2_OP(data['grid'], empty_bi, dirichlet_clear_rows=False, coefficient_function=domain_of_interest)
        print("{}".format(Restricted_L2_OP.apply2(diff_,diff_)[0][0]))
        print("{}".format(Restricted_L2_OP.apply2(diff_,diff_)[0][0]/Restricted_L2_OP.apply2(u_d,u_d)))
# Out:
# 4.292940411541025
# [[0.11353741]]

# %% [markdown]
# # TR-RB approaches

# %%
import time
from pdeopt.model import build_initial_basis
from pdeopt.reductor import QuadraticPdeoptStationaryCoerciveReductor
from pdeopt.TR import TR_algorithm, TR_algorithm_with_optional_enrichment

from pymor.parameters.functionals import MinThetaParameterFunctional
ce = MinThetaParameterFunctional(opt_fom.primal_model.operator.coefficients, mu_bar)

set_defaults({'pymor.operators.constructions.induced_norm.raise_negative': False})
set_defaults({'pymor.operators.constructions.induced_norm.tol': 1e-20})

# %% [markdown]
# ## Newton Method

# %% [markdown]
# ### NCD-corrected

# %% [markdown]
# #### Lagrange Basis (Method 4)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_4' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver,
                 'JFE_start': J_start} # This is not cheating because the quantity to compute this are accessible when preparing pdeopt_reductor
                                       # so the computational time to compute this is already

    extension_params = {'Enlarge_radius': True, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_4, times_4, Js_4, FOC_4, data_4 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space,
                                                TR_parameters, extension_params)
    
    times_full_4_actual, J_error_4_actual, mu_error_4_actual, FOC_4_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_4, Js_4, times_4, tictoc, FOC_4)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.18101441041877248, 0.19528109942313981], heaters: [86.919454021392, 53.085569155559895, 23.27283279772907, 1.1398804277429897, 43.04688182924905, 40.235136003736486, 52.267467135256965], walls: [0.06087938468518019, 0.06665173553667479, 0.06575395131569053]}
# Starting value of the cost: 232.52364603997376
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09811114] 9.884495370123364
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# k: 0 - j 4 - Cost Functional: 160.06971559545286 - mu: {doors: [0.1254901695392159, 0.2], heaters: [80.39614587829311, 49.01166652692734, 23.357021117040258, 0.0, 48.336435144497, 47.344963687112624, 45.80583626365093], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 0.2
# computing the fom gradient since the model was enriched
# First order critical condition: 9.85603008360162
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.19606357] 6.266396202992726
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# k: 1 - j 2 - Cost Functional: 69.31353855723546 - mu: {doors: [0.2, 0.2], heaters: [68.3805640123236, 41.94795832966731, 25.127890745006425, 0.0, 53.455517884982015, 56.176274641305255, 36.00527190308337], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 0.4
# computing the fom gradient since the model was enriched
# First order critical condition: 6.267582838773101
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.38431448] 3.1815909506311
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# enlarging the TR radius to 0.8
# k: 2 - j 2 - Cost Functional: 23.164173317606867 - mu: {doors: [0.16163869119281044, 0.06979258845209549], heaters: [55.84977663998018, 36.34833520868719, 31.83561445435238, 0.0, 53.9174220925992, 56.766743729814095, 30.286365887943944], walls: [0.025, 0.1, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 3.18743871739771
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.7852247] 1.0440205139912158
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# k: 3 - j 3 - Cost Functional: 8.471338270295377 - mu: {doors: [0.08485709631078858, 0.05], heaters: [39.73869387615396, 30.851637508774388, 43.675238656044435, 0.0, 56.40122767599817, 59.15549295823694, 27.638810265982247], walls: [0.025, 0.1, 0.1]}
# enlarging the TR radius to 1.6
# computing the fom gradient since the model was enriched
# First order critical condition: 1.0515035216631485
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [1.56136856] 0.17556580007963224
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# k: 4 - j 3 - Cost Functional: 6.6185798589064895 - mu: {doors: [0.05, 0.05], heaters: [29.407036546427513, 27.917830869315175, 52.69188959388308, 0.0, 58.65855257991675, 60.76609899520594, 27.155870153002915], walls: [0.1, 0.1, 0.1]}
# enlarging the TR radius to 3.2
# computing the fom gradient since the model was enriched
# First order critical condition: 0.17704953250396624
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 0 with residual: 0.21294, because p_k is not a descent direction
# Choosing the gradient as direction
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.12882, because p_k is not a descent direction
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [3.04774003] 0.024528522884278696
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 7 - Cost Functional: 5.930338246889493 - mu: {doors: [0.05, 0.05], heaters: [23.899663449137503, 24.964578773200337, 51.93572666123968, 29.338727848558428, 55.56848853295145, 56.480670528025136, 24.92591558134366], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 6.4
# computing the fom gradient since the model was enriched
# First order critical condition: 0.02378608348275562
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.19312273255630164, J_diff = 0.01955313404893144, FOC = 6.750155989720952e-14
# relative differences mu 0.19312273255630164 and J 0.01955313404893144
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 8 and 8
# k: 6 - j 2 - Cost Functional: 5.813968838548874 - mu: {doors: [0.05, 0.05], heaters: [22.39386595616797, 23.400045556092177, 48.72386028424084, 49.39064492561188, 52.43434373176314, 54.032274197315964, 23.51227892664741], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 12.8
# computing the fom gradient since the model was enriched
# First order critical condition: 0.0002504842357185216
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.001116882115397084, J_diff = 6.893300919480797e-07, FOC = 8.702335715267317e-15
# relative differences mu 0.001116882115397084 and J 6.893300919480797e-07
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 9 and 9
# k: 7 - j 2 - Cost Functional: 5.813965087784689 - mu: {doors: [0.05, 0.05], heaters: [22.381757795845576, 23.395511521349828, 48.69980536043408, 49.373996745187114, 52.35826845509174, 54.12237918418902, 23.5249644674241], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 25.6
# computing the fom gradient since the model was enriched
# First order critical condition: 9.85124769455522e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 8.275171346716974e-05, J_diff = 4.2665350223747625e-09, FOC = 1.1731001391219614e-11
# relative differences mu 8.275171346716974e-05 and J 4.2665350223747625e-09
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 10 and 10
# k: 8 - j 2 - Cost Functional: 5.813965062885975 - mu: {doors: [0.05, 0.05], heaters: [22.38254726782078, 23.396506060133717, 48.70349202111997, 49.374228842279955, 52.3627165810895, 54.11556500590057, 23.52379945031084], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 51.2
# computing the fom gradient since the model was enriched
# First order critical condition: 1.618872740714963e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Subproblem converged: mu_diff = 4.528820806899718e-15, J_diff = 0.0, FOC = 4.38657695472834e-08
# relative differences mu 4.528820806899718e-15 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 11 and 11
# k: 9 - j 6 - Cost Functional: 5.813965062890652 - mu: {doors: [0.05, 0.05], heaters: [22.38254715684377, 23.39650514853719, 48.70348743212683, 49.37422820462705, 52.362720068910704, 54.11556384763508, 23.52380019511646], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.5182305092705826e-08
# *******************************
#
#
# Stopping criteria fulfilled: FOC condition: 4.5182305092705826e-08
# Computing only the initial FOC

# %%
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,mu_error_4_actual)

# %% [markdown]
# #### Lagrange Basis with optional enrichment (Method 4.a)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver,
                 'tau_g': tau_g, 'tau_grad': tau_grad, 'beta_3': beta_3,
                 'minimum_radius': minimum_radius, 'maximum_radius': maximum_radius, 
                 'JFE_start': J_start}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_4bis, times_4bis, Js_4bis, FOC_4bis, data_4bis = TR_algorithm_with_optional_enrichment(opt_rom, pdeopt_reductor, parameter_space,
                                                TR_parameters, extension_params)
    
    times_full_4bis_actual, J_error_4bis_actual, mu_error_4bis_actual, FOC_4bis_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_4bis, Js_4bis, times_4bis, tictoc, FOC_4bis)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.18101441041877248, 0.19528109942313981], heaters: [86.919454021392, 53.085569155559895, 23.27283279772907, 1.1398804277429897, 43.04688182924905, 40.235136003736486, 52.267467135256965], walls: [0.06087938468518019, 0.06665173553667479, 0.06575395131569053]}
# Starting value of the cost: 232.52364603997376
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09811114] 9.884495370123364
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# enlarging the TR radius to 0.2
# k: 0 - j 4 - Cost Functional: 160.0697156469887 - mu: {doors: [0.1254901695392159, 0.2], heaters: [80.39614587829311, 49.01166652692734, 23.357021117040258, 0.0, 48.336435144497, 47.344963687112624, 45.80583626365093], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 9.85603008360162
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.19606357] 6.266396202992726
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# enlarging the TR radius to 0.4
# k: 1 - j 2 - Cost Functional: 69.31353858702914 - mu: {doors: [0.2, 0.2], heaters: [68.3805640123236, 41.94795832966731, 25.127890745006425, 0.0, 53.455517884982015, 56.176274641305255, 36.00527190308337], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 6.267582838773101
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.38431448] 3.1815909506311
# checked sufficient condition
# enlarging the TR radius to 0.8
# Skip_enrichment_step is false, therefore starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# k: 2 - j 2 - Cost Functional: 23.164173317606867 - mu: {doors: [0.16163869119281044, 0.06979258845209549], heaters: [55.84977663998018, 36.34833520868719, 31.83561445435238, 0.0, 53.9174220925992, 56.766743729814095, 30.286365887943944], walls: [0.025, 0.1, 0.025]}
# First order critical condition: 3.18743871739771
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.7852247] 1.0440205139912158
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# enlarging the TR radius to 1.6
# k: 3 - j 3 - Cost Functional: 8.471338274152458 - mu: {doors: [0.08485709631078858, 0.05], heaters: [39.73869387615396, 30.851637508774388, 43.675238656044435, 0.0, 56.40122767599817, 59.15549295823694, 27.638810265982247], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 1.0515035216631485
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [1.56136856] 0.17556580007963224
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# enlarging the TR radius to 3.2
# k: 4 - j 3 - Cost Functional: 6.618579859043166 - mu: {doors: [0.05, 0.05], heaters: [29.407036546427513, 27.917830869315175, 52.69188959388308, 0.0, 58.65855257991675, 60.76609899520594, 27.155870153002915], walls: [0.1, 0.1, 0.1]}
# First order critical condition: 0.17704953250396624
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 0 with residual: 0.21294, because p_k is not a descent direction
# Choosing the gradient as direction
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.12882, because p_k is not a descent direction
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [3.04774003] 0.024528522884278696
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# enlarging the TR radius to 6.4
# k: 5 - j 7 - Cost Functional: 5.930338246449082 - mu: {doors: [0.05, 0.05], heaters: [23.899663449137503, 24.964578773200337, 51.93572666123968, 29.338727848558428, 55.56848853295145, 56.480670528025136, 24.92591558134366], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.02378608348275562
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.19312273255630164, J_diff = 0.01955313404893144, FOC = 6.750155989720952e-14
# relative differences mu 0.19312273255630164 and J 0.01955313404893144
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 8 and 8
# enlarging the TR radius to 12.8
# k: 6 - j 2 - Cost Functional: 5.813968838049277 - mu: {doors: [0.05, 0.05], heaters: [22.39386595616797, 23.400045556092177, 48.72386028424084, 49.39064492561188, 52.43434373176314, 54.032274197315964, 23.51227892664741], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.0002504842357185216
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.001116882115397084, J_diff = 6.893300919480797e-07, FOC = 8.702335715267317e-15
# relative differences mu 0.001116882115397084 and J 6.893300919480797e-07
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 9 and 9
# enlarging the TR radius to 25.6
# k: 7 - j 2 - Cost Functional: 5.813965087277438 - mu: {doors: [0.05, 0.05], heaters: [22.381757795845576, 23.395511521349828, 48.69980536043408, 49.373996745187114, 52.35826845509174, 54.12237918418902, 23.5249644674241], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 9.85124769455522e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 8.275171346716974e-05, J_diff = 4.2665350223747625e-09, FOC = 1.1731001391219614e-11
# relative differences mu 8.275171346716974e-05 and J 4.2665350223747625e-09
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 10 and 10
# enlarging the TR radius to 51.2
# k: 8 - j 2 - Cost Functional: 5.813965062385023 - mu: {doors: [0.05, 0.05], heaters: [22.38254726782078, 23.396506060133717, 48.70349202111997, 49.374228842279955, 52.3627165810895, 54.11556500590057, 23.52379945031084], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 1.618872740714963e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Subproblem converged: mu_diff = 4.528820806899718e-15, J_diff = 0.0, FOC = 4.38657695472834e-08
# relative differences mu 4.528820806899718e-15 and J 0.0
#
# Stopping criteria fulfilled: FOC condition: 4.5182305092705826e-08
# k: 9 - j 6 - Cost Functional: 5.813965062884417 - mu: {doors: [0.05, 0.05], heaters: [22.38254715684377, 23.39650514853719, 48.70348743212683, 49.37422820462705, 52.362720068910704, 54.11556384763508, 23.52380019511646], walls: [0.025, 0.025, 0.025]}
# Computing only the initial FOC

# %%
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,mu_error_4bis_actual)

# %% [markdown]
# #### Directional Taylor Basis (Method 5)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_5' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'AdaptiveTaylor_Newton',  'iterative_solver': iterative_solver,
                 'JFE_start': J_start}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_5, times_5, Js_5, FOC_5, data_5 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_5_actual, J_error_5_actual, mu_error_5_actual, FOC_5_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_5, Js_5, times_5, tictoc, FOC_5)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.18101441041877248, 0.19528109942313981], heaters: [86.919454021392, 53.085569155559895, 23.27283279772907, 1.1398804277429897, 43.04688182924905, 40.235136003736486, 52.267467135256965], walls: [0.06087938468518019, 0.06665173553667479, 0.06575395131569053]}
# Starting value of the cost: 232.52364603997376
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09811114] 9.884495370123364
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 3 and 3
# k: 0 - j 4 - Cost Functional: 160.0697155954524 - mu: {doors: [0.1254901695392159, 0.2], heaters: [80.39614587829311, 49.01166652692734, 23.357021117040258, 0.0, 48.336435144497, 47.344963687112624, 45.80583626365093], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 9.85603008360162
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09971917] 5.1086082817539475
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 5 and 5
# k: 1 - j 4 - Cost Functional: 48.54127217075313 - mu: {doors: [0.2, 0.19786426677776042], heaters: [64.29923417117807, 40.675185010674696, 29.3296823804649, 0.0, 49.186301964886525, 50.23389015265258, 35.71826892740601], walls: [0.025, 0.03154144245816388, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.110969960877162
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09713241] 2.8386174018337478
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 7 and 7
# k: 2 - j 3 - Cost Functional: 20.000964578950686 - mu: {doors: [0.13251754859111034, 0.05932748855320045], heaters: [55.77435513164882, 36.57935358449451, 33.253863066647455, 0.0, 50.14182458157435, 51.43320382558241, 31.012523278237378], walls: [0.025, 0.1, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 2.8398607175711414
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09938141] 1.2994414062588155
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 9 and 9
# k: 3 - j 5 - Cost Functional: 9.60260801068982 - mu: {doors: [0.07435155795029975, 0.05], heaters: [45.311948179414294, 32.69336749006953, 40.187188146467804, 0.0, 52.74478214955939, 54.344181668555684, 28.36821554670158], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.299763735055209
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 0 with residual: 0.42959, because p_k is not a descent direction
# Choosing the gradient as direction
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.15610, because p_k is not a descent direction
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09711894] 0.06503505494837075
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 11 and 11
# k: 4 - j 5 - Cost Functional: 6.522329001766881 - mu: {doors: [0.05, 0.05], heaters: [25.940877479809824, 27.055156746711283, 56.32803186023277, 0.020854613665579055, 59.53310462915587, 61.008375586831626, 27.180556050589352], walls: [0.025, 0.025, 0.041311548180859504]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.06571919527951396
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09826227] 0.043695687165749064
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 13 and 13
# k: 5 - j 3 - Cost Functional: 6.342867659862147 - mu: {doors: [0.05, 0.05], heaters: [25.446408638874185, 26.543243511637908, 55.28508049276618, 6.589258373142058, 58.5207708250079, 60.145668343155876, 26.65776459316282], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.04359805344723803
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.40245842270063853, J_diff = 0.08316174369627423, FOC = 1.0222929752457446e-13
# relative differences mu 0.40245842270063853 and J 0.08316174369627423
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 15 and 15
# k: 6 - j 2 - Cost Functional: 5.813842922297862 - mu: {doors: [0.05, 0.05], heaters: [22.38273551972648, 23.403681256235345, 48.71202918904959, 49.38411811670508, 52.49565130959952, 53.982685706183226, 23.516978320283346], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.00011228368211514315
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0017988324598164234, J_diff = 1.6566420309785032e-06, FOC = 0.0
# relative differences mu 0.0017988324598164234 and J 1.6566420309785032e-06
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 17 and 17
# k: 7 - j 2 - Cost Functional: 5.813965085061012 - mu: {doors: [0.05, 0.05], heaters: [22.38244767469225, 23.395955239790677, 48.70264290276661, 49.37427942165664, 52.35622695494336, 54.12197193633628, 23.524281386416042], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.1533198068981526e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 8.35953554369003e-05, J_diff = 3.808885436560519e-09, FOC = 4.132919663120848e-11
# relative differences mu 8.35953554369003e-05 and J 3.808885436560519e-09
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 19 and 19
# k: 8 - j 2 - Cost Functional: 5.813965062891183 - mu: {doors: [0.05, 0.05], heaters: [22.382547126876368, 23.396504596652278, 48.703484309730015, 49.374227848630326, 52.36272247494999, 54.11556304301215, 23.523800766907094], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 2.294374587782693e-09
# *******************************
#
#
# Stopping criteria fulfilled: FOC condition: 2.294374587782693e-09
# Computing only the initial FOC

# %%
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,mu_error_5_actual)

# %% [markdown]
# #### Directional Taylor Basis with optional enrichment (Method 5.a)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu,  'iterative_solver': iterative_solver,
                 'tau_g': tau_g, 'tau_grad': tau_grad, 'beta_3': beta_3,
                 'minimum_radius': minimum_radius, 'maximum_radius': maximum_radius, 
                 'opt_method': 'AdaptiveTaylor_Newton',  
                 'JFE_start': J_start} 

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_5bis, times_5bis, Js_5bis, FOC_5bis, data_5bis = TR_algorithm_with_optional_enrichment(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_5bis_actual, J_error_5bis_actual, mu_error_5bis_actual, FOC_5bis_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_5bis, Js_5bis, times_5bis, tictoc, FOC_5bis)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.18101441041877248, 0.19528109942313981], heaters: [86.919454021392, 53.085569155559895, 23.27283279772907, 1.1398804277429897, 43.04688182924905, 40.235136003736486, 52.267467135256965], walls: [0.06087938468518019, 0.06665173553667479, 0.06575395131569053]}
# Starting value of the cost: 232.52364603997376
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09811114] 9.884495370123364
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 3 and 3
# enlarging the TR radius to 0.2
# k: 0 - j 4 - Cost Functional: 160.0697156469887 - mu: {doors: [0.1254901695392159, 0.2], heaters: [80.39614587829311, 49.01166652692734, 23.357021117040258, 0.0, 48.336435144497, 47.344963687112624, 45.80583626365093], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 9.85603008360162
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 6 with residual: 4.14763, because p_k is not a descent direction
# Using CG for the linear system
# CG truncated at iteration: 6 with residual: 3.67493, because p_k is not a descent direction
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.19162855] 4.897298381405911
# checked sufficient condition
# enlarging the TR radius to 0.4
# Skip_enrichment_step is false, therefore starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 5 and 5
# k: 1 - j 5 - Cost Functional: 45.05089490394403 - mu: {doors: [0.2, 0.18776800332286486], heaters: [62.08120957763501, 39.98708467534994, 30.187712170702284, 0.0, 49.69283221129736, 51.08583392820123, 35.64563911004918], walls: [0.025, 0.046741001000415665, 0.025]}
# First order critical condition: 4.8996844357848515
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.38900377] 1.7180353949355043
# checked sufficient condition
# enlarging the TR radius to 0.8
# Skip_enrichment_step is false, therefore starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 7 and 7
# k: 2 - j 5 - Cost Functional: 11.454218422515822 - mu: {doors: [0.12825807814135526, 0.05], heaters: [43.493676087652325, 32.651867147741584, 42.14741420588032, 0.0, 54.022037181187166, 55.88331133076994, 29.642865782748505], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 1.7194525535373515
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.17749, because p_k is not a descent direction
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.79208886] 0.033676154869660704
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 9 and 9
# enlarging the TR radius to 1.6
# k: 3 - j 7 - Cost Functional: 6.1502407727109585 - mu: {doors: [0.05, 0.05], heaters: [24.747251896687786, 25.80331748714659, 53.735801510883626, 15.246987121630372, 57.16078998251721, 59.242277984694375, 26.09825205330282], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.03285017915035316
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.3269356944026181, J_diff = 0.05478524196395525, FOC = 5.726925963854325e-13
# relative differences mu 0.3269356944026181 and J 0.05478524196395525
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 11 and 11
# enlarging the TR radius to 3.2
# k: 4 - j 2 - Cost Functional: 5.814176989046246 - mu: {doors: [0.05, 0.05], heaters: [22.43561731880778, 23.478612527058136, 49.06025784783395, 49.52820844520337, 52.71015024702387, 53.46096382230798, 23.41977696877392], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.0006113208016599015
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.008208757707767264, J_diff = 3.8664089360306516e-05, FOC = 3.03543989777123e-14
# relative differences mu 0.008208757707767264 and J 3.8664089360306516e-05
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 13 and 13
# enlarging the TR radius to 6.4
# k: 5 - j 2 - Cost Functional: 5.813965966707428 - mu: {doors: [0.05, 0.05], heaters: [22.38025304392645, 23.39028255024023, 48.68495308596007, 49.37639308264326, 52.33130531764503, 54.15811709857364, 23.52881736051494], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 6.929260760530396e-05
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0005156224923754223, J_diff = 1.5482440192828237e-07, FOC = 8.702335715267317e-15
# relative differences mu 0.0005156224923754223 and J 1.5482440192828237e-07
#
# Stopping criteria fulfilled: FOC condition: 2.802787706273027e-08
# k: 6 - j 2 - Cost Functional: 5.813965062843655 - mu: {doors: [0.05, 0.05], heaters: [22.38254531714834, 23.39650283111117, 48.70347357681884, 49.37422774751202, 52.36273530250744, 54.11556073733377, 23.52380244454372], walls: [0.025, 0.025, 0.025]}
# Computing only the initial FOC

# %%
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,mu_error_5bis_actual)

# %% [markdown]
# ### Aggregated

# %% [markdown]
# #### excluding directional sensitivities (Method 6) -- (b)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)

if 'Method_6' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                unique_basis=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_6, times_6, Js_6, FOC_6, data_6 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_6_actual, J_error_6_actual, mu_error_6_actual, FOC_6_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_6, Js_6, times_6, tictoc, FOC_6)

# %%
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual, mu_error_6_actual)

# %% [markdown]
# #### including directional sensitivities (Method 7) -- (d)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)

if 'Method_7' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                unique_basis=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'estimate_tolerance': estimate_tolerance, 
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'AdaptiveTaylor_Newton',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_7, times_7, Js_7, FOC_7, data_7 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_7_actual, J_error_7_actual, mu_error_7_actual, FOC_7_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_7, Js_7, times_7, tictoc, FOC_7)

# %%
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,mu_error_7_actual)

# %% [markdown]
# ## NCD corrected BFGS Method (KMSOV'20)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_8' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'BFGSMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_8, times_8, Js_8, FOC_8, data_8 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_8_actual, J_error_8_actual, mu_error_8_actual, FOC_8_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_8, Js_8, times_8, tictoc, FOC_8)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.18101441041877248, 0.19528109942313981], heaters: [86.919454021392, 53.085569155559895, 23.27283279772907, 1.1398804277429897, 43.04688182924905, 40.235136003736486, 52.267467135256965], walls: [0.06087938468518019, 0.06665173553667479, 0.06575395131569053]}
# Starting value of the cost: 232.52364603997376
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# k: 0 - j 3 - Cost Functional: 125.74609077185573 - mu: {doors: [0.05968866043792695, 0.2], heaters: [83.18507387864832, 49.25712299589735, 21.323698840914094, 0.0, 40.93454575482081, 38.06629130992842, 44.60907628855586], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.608338192093543
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# k: 1 - j 3 - Cost Functional: 36.92663591653019 - mu: {doors: [0.05218034599774866, 0.19994354705044476], heaters: [78.05444628965986, 44.01050429935769, 18.650828707891453, 0.0, 37.998471226054136, 35.0315049757358, 34.10488026788932], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.182902549083313
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# k: 2 - j 8 - Cost Functional: 9.687268161004713 - mu: {doors: [0.05, 0.05], heaters: [72.8555999423637, 38.92708895610155, 16.164769115436478, 0.05605132517677108, 35.237527349413014, 32.18377079662486, 24.11563025074956], walls: [0.045065454985355295, 0.03148747157008351, 0.04634636151677596]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.15176654321996955
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# k: 3 - j 4 - Cost Functional: 9.486971153186072 - mu: {doors: [0.05, 0.05], heaters: [71.34028837777443, 38.72879460419644, 16.666067564782637, 0.7169916809422016, 35.61604702745119, 32.61289781421865, 24.82387981543118], walls: [0.1, 0.09995724509016507, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.13740818802201116
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# k: 4 - j 6 - Cost Functional: 9.113946448224091 - mu: {doors: [0.05, 0.05], heaters: [67.13206174097982, 37.62096665260049, 17.55903358643479, 1.9959327145269088, 36.17601200380346, 33.27785248099806, 25.17474275039314], walls: [0.1, 0.09995267720955871, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.25376192054503927
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -0.0021369770041328976
# Reset direction to - gradient
# Curvature condition: -0.001747621053513177
# Reset direction to - gradient
# Curvature condition: -0.0005095823561332253
# Reset direction to - gradient
# Curvature condition: -0.0003019253881094422
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 9 - Cost Functional: 6.552337414941544 - mu: {doors: [0.05, 0.05], heaters: [23.097651330465453, 29.455138542080636, 31.214676562261285, 20.480212265456455, 45.80915031305524, 44.25663247885475, 37.11452623930899], walls: [0.042534732570489585, 0.02788905904789384, 0.07392613426367095]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.06070623739873183
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -0.0025302091715453984
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 8 and 8
# k: 6 - j 28 - Cost Functional: 6.09175466797996 - mu: {doors: [0.05, 0.05], heaters: [27.569374646372147, 30.35445211914361, 37.14455875031587, 28.530317639133578, 50.100138397931644, 49.23077158875794, 28.38634731201385], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.07600169954373145
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 9 and 9
# k: 7 - j 32 - Cost Functional: 5.888422721833598 - mu: {doors: [0.05, 0.05], heaters: [25.42477597913442, 26.348844194705716, 42.70891373444002, 36.88402143005483, 53.18526497664363, 53.1347783341844, 25.45078130002534], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.012901039748976616
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 10 and 10
# k: 8 - j 255 - Cost Functional: 5.814099011902879 - mu: {doors: [0.05, 0.05], heaters: [22.510331706048518, 23.36804220320984, 48.84529460417423, 49.39812303824866, 52.63404403632981, 54.01989727080885, 23.364684039055685], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.005534425955669332
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 1.9506666869347826e-07, mu_diff = 2.623630016104085e-15, J_diff = 0.0
# relative differences mu 2.623630016104085e-15 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 11 and 11
# k: 9 - j 301 - Cost Functional: 5.813965216670349 - mu: {doors: [0.05, 0.05], heaters: [22.38268273972204, 23.396637969551097, 48.69727213535574, 49.375573699305576, 52.34763839345146, 54.13386477276747, 23.523818852447295], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.2527285046900919e-05
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 4.594204656847339e-07, mu_diff = 1.9279906559703567e-12, J_diff = 0.0
# relative differences mu 1.9279906559703567e-12 and J 0.0
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 12 and 12
# k: 10 - j 19 - Cost Functional: 5.813965062952313 - mu: {doors: [0.05, 0.05], heaters: [22.38239733165368, 23.396458090627352, 48.70359046151386, 49.37451714916301, 52.362557824348926, 54.11548867448546, 23.523860303075594], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.598591719182571e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.820435213494928e-07, mu_diff = 1.7179119583226665e-15, J_diff = 0.0
# relative differences mu 1.7179119583226665e-15 and J 0.0
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 13 and 13
# k: 11 - j 5 - Cost Functional: 5.813965062948206 - mu: {doors: [0.05, 0.05], heaters: [22.38240224154069, 23.396459114167993, 48.703589100986704, 49.37451407652367, 52.36255898295861, 54.115489006466895, 23.5238544628541], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.808665774299645e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.61147301151818e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 14 and 14
# k: 12 - j 6 - Cost Functional: 5.813965062944776 - mu: {doors: [0.05, 0.05], heaters: [22.382404858350917, 23.396460886073402, 48.703589571455176, 49.374514146500054, 52.362560135267834, 54.115489992154174, 23.523856221968927], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.620626561171649e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -1.0782976568552313e-28
# Reset direction to - gradient
# Curvature condition: -9.037482687765944e-33
# Reset direction to - gradient
# Subproblem converged: FOC = 4.5668661930863653e-07, mu_diff = 4.570952051588922e-17, J_diff = 3.055327681142189e-16
# relative differences mu 4.570952051588922e-17 and J 3.055327681142189e-16
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 15 and 15
# k: 13 - j 7 - Cost Functional: 5.813965062946735 - mu: {doors: [0.05, 0.05], heaters: [22.38240527588006, 23.39646089841517, 48.703589379418716, 49.37451377042125, 52.362560208584114, 54.11548997510725, 23.523855449696107], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.57289850993336e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 4.566817899778239e-07, mu_diff = 2.5036135479297706e-16, J_diff = 0.0
# relative differences mu 2.5036135479297706e-16 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 16 and 16
# k: 14 - j 1 - Cost Functional: 5.81396506294749 - mu: {doors: [0.05, 0.05], heaters: [22.382405275880075, 23.39646089841517, 48.70358937941871, 49.374513770421245, 52.362560208584114, 54.11548997510725, 23.523855449696086], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.5728984363493913e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 1.0332291490953826e-06, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 17 and 17
# k: 15 - j 4 - Cost Functional: 5.8139650629491815 - mu: {doors: [0.05, 0.05], heaters: [22.382409103407056, 23.39646134863214, 48.70358795041753, 49.37451080087912, 52.3625610216844, 54.115490037863566, 23.523849691737386], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.0319978206191317e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 4.1610283170026837e-07, mu_diff = 4.909253582068582e-15, J_diff = 0.0
# relative differences mu 4.909253582068582e-15 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 18 and 18
# k: 16 - j 5 - Cost Functional: 5.8139650629429465 - mu: {doors: [0.05, 0.05], heaters: [22.38241074985004, 23.396462515669732, 48.7035882935158, 49.374510906182685, 52.36256177704248, 54.11549069649545, 23.523851026704783], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.156290626383355e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -2.053572268005173e-30
# Reset direction to - gradient
# Subproblem converged: FOC = 4.974002470563248e-07, mu_diff = 7.22730976102231e-17, J_diff = 0.0
# relative differences mu 7.22730976102231e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 19 and 19
# k: 17 - j 7 - Cost Functional: 5.813965062935052 - mu: {doors: [0.05, 0.05], heaters: [22.382419639142135, 23.396465384718365, 48.70358672519959, 49.37450646850903, 52.36256451237303, 54.11549207178483, 23.523845032681795], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.964942168493875e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 6.173105088708308e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 20 and 20
# k: 18 - j 5 - Cost Functional: 5.813965062940248 - mu: {doors: [0.05, 0.05], heaters: [22.382422532117005, 23.396466984785285, 48.70358686295048, 49.374505948881634, 52.36256569425643, 54.115492959030945, 23.52384572701295], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 6.18384032835296e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -4.529183495300196e-31
# Reset direction to - gradient
# Subproblem converged: FOC = 7.215004781294212e-07, mu_diff = 3.2321511930884336e-17, J_diff = 0.0
# relative differences mu 3.2321511930884336e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 21 and 21
# k: 19 - j 7 - Cost Functional: 5.813965062938562 - mu: {doors: [0.05, 0.05], heaters: [22.38242313398936, 23.39646632268821, 48.70358588758519, 49.374504353279875, 52.36256557411453, 54.11549252354622, 23.523842104549008], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 7.203358548089761e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 5.468850112868142e-07, mu_diff = 6.563991205182943e-09, J_diff = 0.0
# relative differences mu 6.563991205182943e-09 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 22 and 22
# k: 20 - j 1 - Cost Functional: 5.813965062936452 - mu: {doors: [0.05, 0.05], heaters: [22.38242361328905, 23.396466640967517, 48.70358596288064, 49.37450434324151, 52.36256579167815, 54.11549270481236, 23.523842426373946], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.458632264677025e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -3.8584859153311868e-31
# Reset direction to - gradient
# Subproblem converged: FOC = 5.468804626816529e-07, mu_diff = 5.59825006095097e-17, J_diff = 3.055327681145488e-16
# relative differences mu 5.59825006095097e-17 and J 3.055327681145488e-16
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 21 - j 2 - Cost Functional: 5.813965062939941 - mu: {doors: [0.05, 0.05], heaters: [22.382423613289824, 23.39646664096798, 48.7035859628807, 49.37450434324141, 52.36256579167848, 54.11549270481262, 23.523842426374262], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.458630223653449e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -3.406427463428681e-30
# Reset direction to - gradient
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452048157271215e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 22 - j 4 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598868, 23.396466644711786, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.52384242893127], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -4.537033916772728e-31
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976899589858e-07, mu_diff = 4.570952033743907e-17, J_diff = 0.0
# relative differences mu 4.570952033743907e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 23 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.38242361959887, 23.39646664471179, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.52384242893127], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 7.917121161404736e-17, J_diff = 0.0
# relative differences mu 7.917121161404736e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 24 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 25 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 26 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 27 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 28 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 24
# k: 29 - j 1 - Cost Functional: 5.8139650629359565 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451976858339197e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 30 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 31 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 32 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 33 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 34 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 25
# k: 35 - j 1 - Cost Functional: 5.81396506293642 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451985920939788e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 36 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 37 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 38 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 39 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 40 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 41 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 42 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 26
# k: 43 - j 1 - Cost Functional: 5.813965062936958 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.451996803851258e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 44 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 45 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 46 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 47 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 48 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 49 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 50 - j 1 - Cost Functional: 5.813965062938632 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452031097472872e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 51 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 52 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 53 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 54 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 55 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 56 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 57 - j 1 - Cost Functional: 5.813965062939195 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452042283501496e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 29
# k: 58 - j 1 - Cost Functional: 5.813965062937292 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 5.452003147798501e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 29
# k: 59 - j 1 - Cost Functional: 5.813965062937292 - mu: {doors: [0.05, 0.05], heaters: [22.382423619598878, 23.396466644711793, 48.703585963420174, 49.37450434243753, 52.362565794381695, 54.11549270692259, 23.523842428931275], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 5.441825063309709e-07
# *******************************
#
#  WARNING: Maximum number of iteration for the TR algorithm reached
# Computing only the initial FOC

# %%
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,mu_error_8_actual)

# %% [markdown]
# ## Qian-Grepl-Method

# %%
#Qian-Grepl

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)
tic = time.time()
params = [mu]

if 'Method_9' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(opt_fom, params)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                                RBbasis, dual_RBbasis, 
                                                                opt_product=opt_fom.opt_product, 
                                                                prepare_for_hessian=False,
                                                                prepare_for_gradient_estimate=True,
                                                                coercivity_estimator=ce, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()
    tictoc = time.time() - tic
    
    TR_parameters = {'Qian-Grepl': True,
                 'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'BFGSMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_9, times_9, Js_9, FOC_9, data_9 = TR_algorithm(
        opt_rom, pdeopt_reductor, parameter_space, TR_parameters, extension_params)

    times_full_9_actual, J_error_9_actual, FOC_9_actual, mu_error_9_actual = compute_actual_errors(
        opt_fom, parameter_space, J_start, J_opt, mus_9, times_9, tictoc, mu, mu_opt_as_array)

# %%
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,J_error_9_actual)

# %% [markdown]
# # Results

# %%
print(mu_opt)
u = opt_fom.solve(mu_opt)
opt_fom.visualize(u)
# Out:
# {doors: [0.05, 0.05], heaters: [22.38254711947, 23.39650455721, 48.70348426512, 49.37422778852, 52.36272251326, 54.11556305764, 23.52380079299], walls: [0.025, 0.025, 0.025]}
# Output()

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### J error

# %%
timings_figure = plt.figure()
if 'SH' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,J_error_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,J_error_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,J_error_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,J_error_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag. optional')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,J_error_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay. optional')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual,J_error_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,J_error_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,J_error_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,J_error_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('True optimization error of the output functional')
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Plot FOC

# %%
timings_figure = plt.figure()

if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH, FOC_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual, FOC_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual, FOC_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual, FOC_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag.')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual, FOC_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay.')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual, FOC_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual, FOC_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual, FOC_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual, FOC_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('First-order critical condition')
# plt.xlim([-1,30])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Plot Mu error

# %%
if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,mu_error_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,mu_error_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,mu_error_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,mu_error_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag.')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,mu_error_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay.')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual,mu_error_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,mu_error_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,mu_error_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,mu_error_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('Mu error')
#plt.xlim([-1,100])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Save the data

# %%
#save data
from pdeopt.tools import save_data

directory = f'results/Starter{seed}'

if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_SH, J_error_SH, 1, mu_error=mu_error_SH, FOC=FOC_SH)
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_4_actual, J_error_4_actual, 4, mu_error=mu_error_4_actual, FOC=FOC_4_actual, additional_data=data_4)
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_5_actual, J_error_5_actual, 5, mu_error=mu_error_5_actual, FOC=FOC_5_actual, additional_data=data_5)
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_4bis_actual, J_error_4bis_actual, 2, mu_error=mu_error_4bis_actual, FOC=FOC_4bis_actual, additional_data=data_4bis)
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_5bis_actual, J_error_5bis_actual, 3, mu_error=mu_error_5bis_actual, FOC=FOC_5bis_actual, additional_data=data_5bis)
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_6_actual, J_error_6_actual, 6, mu_error=mu_error_6_actual, FOC=FOC_6_actual, additional_data=data_6)
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_7_actual, J_error_7_actual, 7, mu_error=mu_error_7_actual, FOC=FOC_7_actual, additional_data=data_7)
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_8_actual, J_error_8_actual, 8, mu_error=mu_error_8_actual, FOC=FOC_8_actual, additional_data=data_8)
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_9_actual, J_error_9_actual, 9, mu_error=mu_error_9_actual, FOC=FOC_9_actual, additional_data=data_9)
