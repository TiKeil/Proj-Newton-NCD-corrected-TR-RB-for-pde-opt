# %% [markdown]
# # TR-RB simulation

# %%
# ~~~
# This file is part of the paper:
#
#           "An adaptive projected Newton non-conforming dual approach
#         for trust-region reduced basis approximation of PDE-constrained
#                           parameter optimization"
#
#   https://github.com/TiKeil/Proj-Newton-NCD-corrected-TR-RB-for-pde-opt
#
# Copyright 2019-2020 all developers. All rights reserved.
# License: Licensed as BSD 2-Clause License (http://opensource.org/licenses/BSD-2-Clause)
# Authors:
#   Luca Mechelli (2019 - 2020)
#   Tim Keil      (2019 - 2020)
# ~~~

# %% [markdown]
# # Preparations

# %% [markdown]
# ## details

# %% [markdown]
# In this notebook we discretize the following problem:
# Find $u_{\mu}$ solving the following parametrized constrained equation
#
# \begin{align*}
# 	-  \nabla \cdot \left( \kappa_{\mu}  \nabla u_{\mu} \right) &= f_{\mu} &&\text{in } \Omega, \\
# 	q ( \kappa_{\mu}  \nabla u_{\mu} \cdot n) &= (u_{\text{out}} - u_{\mu}) &&\text{on } \partial \Omega.
# \end{align*}

# %% [markdown]
# For the definition of $\kappa_{\mu}$ and $f_{\mu}$ in the computational domain $\Omega$, we use the `BitmapFunction` from PyMOR. This function uses the Python Imaging Library (PIL) in order to convert a .png grayscale picture to a data function on our domain.
# Walls, windows and doors are stored in seperated .png to enable a affine decomposition of each part of the picture. Furthermore, we are considering a heater at each window. The numbering of the components for $\kappa_{\mu}$ can be seen in the following picture
# ![EXC_notebook_data/EXC_MM_with_numbers.png](../../EXC_notebook_data/Domain_of_interestin_Omega.png)
#
# Here, numbers with | are walls, numbers with _ are doors and numbers with dots are windows
#
# The heaters are numbered in the following way:
# ![EXC_notebook_data/EXC_MM_with_numbers_heat.png](../../EXC_notebook_data/EXC_MM_with_numbers_heat.png)

# %% [markdown]
# For our pde constrained model, we need to define a cost functional. In a general quadratic model, we have
#
# \begin{align}
# \mathcal{J}(u, \mu) := \Theta(\mu) + j_\mu(u) + k_\mu(u, u),
# \end{align}
#
# For this code, we restrict ourselves to the following definition
# \begin{align}
# \mathcal{J}(v, \mu) = \frac{\sigma_d}{2} \int_{D}^{} (v - u^{\text{d}})^2 + \frac{1}{2} \sum^{M}_{i=1} \sigma_i \mu_i^2,
# \end{align}
# which means
#
# \begin{align}
# \Theta(\mu) &= \frac{1}{2} \sum^{M}_{i=1} \sigma_i \mu_i^2 + \frac{\sigma_d}{2} \int_{D}^{} u^{\text{d}} u^{\text{d}}\\
# j_{\mu}(u) & = -\sigma_d \int_{D}^{} u^{\text{d}}u \\
# k_{\mu}(u,u) &= \frac{\sigma_d}{2} \int_{D}^{} u^2
# \end{align}
#
# The following code implements this particular case.

# %% [markdown]
# ## prepare cells

# %%
import numpy as np

from matplotlib import pyplot as plt

from pymor.basic import *
set_log_levels({'pymor': 'WARN'})

# %%
from pymor.core.logger import set_log_levels, getLogger
set_log_levels({'pymor': 'ERROR',
                'distributed_adaptive_discretizations': 'DEBUG',
                'notebook': 'INFO'})
logger = getLogger('notebook.notebook')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12.0, 8.0)
mpl.rcParams['font.size'] = 12
mpl.rcParams['savefig.dpi'] = 300

data_path = '../../../EXC_data'
# domain of interest
bounding_box = [[0,0],[2,1]]
domain_of_interest = BitmapFunction('{}/Domain_of_interest.png'.format(data_path), range=[1,0], bounding_box=bounding_box)

# %% [markdown]
# ## problem definition and tolerances

# %%
from pdeopt.problems import EXC_problem, set_input_dict
from pdeopt.discretizer import discretize_quadratic_pdeopt_stationary_cg

parametric_quantities = {'walls': [1,4,9], 'windows': [], 'doors': [6,7], 'heaters': [1,3,5,6,7,8,9]}
inactive_quantities = {'removed_walls': [], 'open_windows': [], 'open_doors': [1,2,3,4,5,10], 'active_heaters': []}
summed_quantities = {'walls': [[1,2,3,7,8],[4,5,6]], 'windows': [], 'doors': [], 'heaters': [[1,2],[3,4],[9,10,11,12]]}

coefficient_expressions = None

parameters_in_q = True
input_dict = set_input_dict(parametric_quantities, inactive_quantities, coefficient_expressions, summed_quantities, parameters_in_q,
                            ac=0.5, owc=[0.025,0.1], iwc= [0.025,0.1], idc=[0.05,0.2], wc=[0.0005], ht=[0,100],
                                    owc_c=0.001,  iwc_c= 0.025,     idc_c=0.01,  wc_c=0.05,  ht_c=80)


parameter_scaling = False
u_out = 5

problem, parameter_scales = EXC_problem(input_dict, summed_quantities, outside_temperature=u_out, #, q_inverse=0.0001
                                        data_path = data_path,parameters_in_q=parameters_in_q, 
                                        parameter_scaling=parameter_scaling,
                                        coefficient_expressions=coefficient_expressions)

u_d = 18 

mu_d = problem.parameter_space.sample_randomly(1, seed=10)[0]
mu_d = None

sigma_d = 100
weights = {'walls': 0.1, 'doors': 1, 'heaters': [0.002,0.002,0.0005,0.0005,0.0005,0.0005,0.004], 'windows': 1, 'state': sigma_d}

diameter = np.sqrt(2)/200.
opt_fom, data, mu_bar = discretize_quadratic_pdeopt_stationary_cg(problem, diameter, weights, parameter_scales, 
                                                          domain_of_interest, desired_temperature=u_d, 
                                                          mu_for_u_d=mu_d, mu_for_tikhonov=mu_d,
                                                          parameters_in_q=parameters_in_q, product='fixed_energy')
# Out:
# I am using the NCD corrected functional!!
# my product is fixed_energy
# mu_bar is: {doors: [0.1, 0.1], heaters: [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0], walls: [0.049999999999999996, 0.049999999999999996, 0.049999999999999996]}

# %%
print('Information on the grid:')
print(data['grid'])

seed = 2                   # random seed for the starting value
radius = 0.1               # TR radius 
FOC_tolerance = 1e-7       # tau_FOC
sub_tolerance = 1e-8       # tau_sub
safety_tol = 1e-16         # Safeguard, to avoid running the optimizer for really small difference in digits
max_it = 60                # Maximum number of iteration for the TR algorithm
max_it_sub = 400           # Maximum number of iteration for the TR optimization subproblem
max_it_SH = 800            # Maximum number of iteration for the TR Steihaug method
max_it_arm = 50            # Maximum number of iteration for the Armijo rule
init_step_armijo = 0.5     # Initial step for the Armijo rule
armijo_alpha = 1e-4        # kappa_arm
beta = 0.95                # beta_2
epsilon_i = 1e-8           # Treshold for the epsilon active set (Kelley '99)
iterative_solver = 'CG'    # chosen iterative solver

# parameter control
control_mu = False         # enable post processing for the optimal parameter estimation

# optional enrichment
tau_g = FOC_tolerance/sub_tolerance
tau_grad = 0.01
beta_3 = 1./2
minimum_radius = 1e-6
maximum_radius = 1e16

# some implementational variables
Qian_Grepl_subproblem = True
reductor_type = 'simple_coercive'
# Out:
# Information on the grid:
# Rect-Grid on domain [0,2] x [0,1]
# x0-intervals: 400, x1-intervals: 200
# faces: 80000, edges: 160600, vertices: 80601

# %%
# starting with 
parameter_space = problem.parameter_space
mu = parameter_space.sample_randomly(1, seed=seed)[0]

# %% [markdown]
# ### What methods do you want to test ?

# %%
optimization_methods = [
    # FOM Method
    'SH',   # Steihaug Version 4
    # Newton 
        # NCD-corrected
         'Method_4', # TR-RB (a)
         'Method_4_optional',
         'Method_5', # TR-RB (c)
         'Method_5_optional',
        # Aggregated
#          'Method_6', # TR-RB (b) 
#          'Method_7', # TR-RB (d)
    # BFGS
        # NCD-corrected from KMSOV'20
         'Method_8', # TR-RB
    # Qian Grepl method from QGVW'17
#          'Method_9'
]

#optimization_methods = ['All']

# %% [markdown]
# ## Visualizations

# %% [markdown]
# Visualize diffusion and rhs

# %%
from pymor.discretizers.builtin.cg import InterpolationOperator

vis_mu = mu.copy()
diff = InterpolationOperator(data['grid'], problem.diffusion).as_vector(vis_mu)
rhs = InterpolationOperator(data['grid'], problem.rhs).as_vector(vis_mu)
doI = InterpolationOperator(data['grid'], domain_of_interest).as_vector(vis_mu)

opt_fom.visualize(diff)
# Out:
# Output()

# %%
opt_fom.visualize(rhs)
# Out:
# Output()

# %%
opt_fom.visualize(doI)
# Out:
# Output()

# %% [markdown]
# We can easily solve the primal and dual equations by calling

# %%
u = opt_fom.solve(mu)
p = opt_fom.solve_dual(mu)

opt_fom.visualize(u)
# Out:
# Output()

# %%
opt_fom.visualize(p)
# Out:
# Output()

# %% [markdown]
# # Full Order Optimization

# %%
parameters = opt_fom.parameters
if mu_d is not None:
    mu_opt = mu_d
else:
    #use result from previous FOM run
    mu_opt = parameters.parse(np.array([5.000000000000e-02,  5.000000000000e-02,  2.238254711947e+01,
  2.339650455721e+01,  4.870348426512e+01,  4.937422778852e+01,
  5.236272251326e+01,  5.411556305764e+01,  2.352380079299e+01,
  2.500000000000e-02,  2.500000000000e-02,  2.500000000000e-02]))
    
mu_opt_as_array = mu_opt.to_numpy()
J_opt = opt_fom.output_functional_hat(mu_opt)
print('Optimal parameter: ', mu_opt_as_array)
print('Optimal J: ', J_opt)

print()
print('Starting parameter: ', mu.to_numpy())
J_start = opt_fom.output_functional_hat(mu)
print('Starting J: ', J_start)
# Out:
# Optimal parameter:  [5.00000000e-02 5.00000000e-02 2.23825471e+01 2.33965046e+01
#  4.87034843e+01 4.93742278e+01 5.23627225e+01 5.41155631e+01
#  2.35238008e+01 2.50000000e-02 2.50000000e-02 2.50000000e-02]
# Optimal J:  5.813965062384796
#
# Starting parameter:  [1.15399235e-01 5.38889348e-02 5.49662478e+01 4.35322393e+01
#  4.20367802e+01 3.30334821e+01 2.04648634e+01 6.19270966e+01
#  2.99654674e+01 4.50120456e-02 7.15850375e-02 6.46856571e-02]
# Starting J:  41.96687786761413

# %%
print(mu_opt.parameters)
# Out:
# {doors: 2, heaters: 7, walls: 3}

# %% [markdown]
# # TR Steihaug

# %%
from pdeopt.TR import TR_Steihaug
from pdeopt.tools import compute_errors

TR_parameters = {'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'max_iterations_subproblem': max_it_sub,
                 'max_iterations': max_it_SH,
                 'starting_parameter': mu, 
                 'epsilon_i': epsilon_i,
                 'max_iterations_armijo': max_it_arm, 'initial_step_armijo': init_step_armijo,
                 'armijo_alpha': armijo_alpha,
                 'full_order_model': True,
                 'iterative_solver': iterative_solver}

if 'SH'  in optimization_methods or 'All' in optimization_methods:
    mus_SH, times_SH, Js_SH, FOC_SH = TR_Steihaug(opt_fom, problem.parameter_space, TR_parameters)
    times_full_SH, J_error_SH, mu_error_SH, FOC = compute_errors(opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, 
                                                       mus_SH, Js_SH, times_SH, 0, FOC_SH)
# Out:
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.2
# k: 1 - Cost Functional: 39.59386737218347 - mu: {doors: [0.08929694839547211, 0.09104559723717451], heaters: [54.76624778787091, 43.33223926182769, 41.8367802087489, 32.83348210038741, 20.26486340378425, 61.72709663506637, 29.765467367452313], walls: [0.026405815438250428, 0.0980038925678855, 0.09751922170313206]}
# First order critical condition: 4.664957289045249
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.4
# k: 2 - Cost Functional: 35.43121201112672 - mu: {doors: [0.05560606489711542, 0.11165405261220102], heaters: [54.36624778787091, 42.93223926182769, 41.4367802087489, 32.43348210038741, 19.864863403784252, 61.32709663506637, 29.365467367452315], walls: [0.025200552279553257, 0.09971523723182187, 0.09964609455198309]}
# First order critical condition: 4.354080976680329
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 0.8
# k: 3 - Cost Functional: 27.995829633663107 - mu: {doors: [0.051639853094693926, 0.10555801531945343], heaters: [53.566247787870914, 42.13223926182769, 40.6367802087489, 31.633482100387408, 19.06486340378425, 60.52709663506637, 28.565467367452314], walls: [0.025058664371945205, 0.09991670287176112, 0.09989647766217295]}
# First order critical condition: 3.736155172458697
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 1.6
# k: 4 - Cost Functional: 16.538081833289198 - mu: {doors: [0.05100960507673419, 0.09167084954131156], heaters: [51.96624778787091, 40.53223926182769, 39.0367802087489, 30.033482100387406, 17.46486340378425, 58.92709663506637, 26.965467367452312], walls: [0.02503611777660508, 0.09994871662356862, 0.09993626460921179]}
# First order critical condition: 2.5007057551146405
# ***********************************************
#
# Computing at first the Cauchy point
# The model function admits a point that has all components on the boundary
#  Returning the direction to reach it to continue
# Using CG-Steihaug for the linear system
# Enlarging the radius to 3.2
# k: 5 - Cost Functional: 7.25864037627116 - mu: {doors: [0.05123488810657449, 0.10096927271391773], heaters: [48.76624778787091, 37.33223926182769, 36.01301437818888, 27.012154288379477, 14.428167925281675, 55.84089957167526, 23.765467367452313], walls: [0.025044177088441155, 0.0999372732634973, 0.09992204270970305]}
# First order critical condition: 0.13318103227202585
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# CG-Steihaug truncated at iteration: 3 with residual: 0.37928, because H_k is not pos def
# Enlarging the radius to 6.4
# k: 6 - Cost Functional: 7.203135490341765 - mu: {doors: [0.05, 0.09229038683401822], heaters: [48.085305730534856, 36.916945584105804, 36.02350807290499, 27.074632383823992, 14.572795732407833, 55.76269404702286, 23.527314263773484], walls: [0.07393921889129852, 0.024999999999999994, 0.02500000000000001]}
# First order critical condition: 0.10735720517249982
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 12.8
# k: 7 - Cost Functional: 6.741899033153686 - mu: {doors: [0.05, 0.05000346988598007], heaters: [41.60909546083833, 34.15865645191056, 37.7755778754248, 29.593934741466228, 18.39668111577472, 56.49521027107602, 26.179419565135092], walls: [0.0999978617377197, 0.025, 0.025]}
# First order critical condition: 0.08716659830464057
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 25.6
# k: 8 - Cost Functional: 6.137778750006191 - mu: {doors: [0.05, 0.05], heaters: [28.584584596928313, 27.955007425381556, 42.48156812565895, 36.45577262791778, 28.888348236856675, 58.248125862053804, 28.960369737523898], walls: [0.1, 0.025, 0.025]}
# First order critical condition: 0.06487718247154103
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 51.2
# k: 9 - Cost Functional: 5.816056964782547 - mu: {doors: [0.05, 0.05], heaters: [22.60319213924792, 23.541260442995117, 48.67762069632691, 49.14047604353048, 51.78855105516352, 54.00892760814274, 23.466167041510623], walls: [0.025000000000001493, 0.025, 0.025]}
# First order critical condition: 0.03566669598995548
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Enlarging the radius to 102.4
# k: 10 - Cost Functional: 5.814139811209316 - mu: {doors: [0.05, 0.05], heaters: [22.619562547637187, 23.566816173834987, 48.70077092974406, 49.18340217128845, 51.86489078666449, 54.04240957915881, 23.551999856751998], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.003343815538340112
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 11 - Cost Functional: 5.8139805790463015 - mu: {doors: [0.05, 0.05], heaters: [22.401142764284103, 23.408791483868107, 48.70142995099052, 49.35390843579962, 52.31251511170485, 54.106456017840834, 23.519313557450285], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.0030717079387814427
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 12 - Cost Functional: 5.813966359292635 - mu: {doors: [0.05, 0.05], heaters: [22.402592429819794, 23.411010373063654, 48.70340818362956, 49.35762462339555, 52.31916400672851, 54.109333525859434, 23.52665848922643], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.0002879958137796699
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 13 - Cost Functional: 5.813965177403588 - mu: {doors: [0.05, 0.05], heaters: [22.384113164628353, 23.397546994374032, 48.70332319657671, 49.37246425553563, 52.3583386335532, 54.11478704608823, 23.523453095999642], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.00026445557288030523
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 14 - Cost Functional: 5.813965072003157 - mu: {doors: [0.05, 0.05], heaters: [22.384241394088182, 23.397739565290173, 48.703492085642026, 49.37278565402065, 52.35891707428601, 54.11503411766221, 23.52408161393325], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.4796107404154405e-05
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 15 - Cost Functional: 5.81396506323631 - mu: {doors: [0.05, 0.05], heaters: [22.382678923114852, 23.39659296704183, 48.70347184352962, 49.374074930196166, 52.362340250702246, 54.11549707822873, 23.52377398933166], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.2761132240843795e-05
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 16 - Cost Functional: 5.813965062456873 - mu: {doors: [0.05, 0.05], heaters: [22.382690252141675, 23.39660967215479, 48.70348624857341, 49.37410270351783, 52.36239052097397, 54.115518274229295, 23.52382777385633], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.134257526441747e-06
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 17 - Cost Functional: 5.813965062391844 - mu: {doors: [0.05, 0.05], heaters: [22.382558207144065, 23.396512053482734, 48.70348332606199, 49.374214556276165, 52.36268922075318, 54.11555745939779, 23.523798738214406], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 1.958479652239495e-06
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 18 - Cost Functional: 5.81396506238616 - mu: {doors: [0.05, 0.05], heaters: [22.38255920678642, 23.39651350192126, 48.70348455564935, 49.37421695518627, 52.36269358555265, 54.11555927400533, 23.52380334101265], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 1.836543367939866e-07
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# k: 19 - Cost Functional: 5.813965062385705 - mu: {doors: [0.05, 0.05], heaters: [22.382548051629545, 23.396505192519818, 48.70348421337536, 49.3742266519687, 52.36271961678992, 54.11556256247597, 23.523800636342816], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 1.6847638110502514e-07
# ***********************************************
#
# Computing at first the Cauchy point
# Using CG-Steihaug for the linear system
# Shrinking the radius to 51.2
# Method is stagnating, safety tolerance reached so stopping...

# %%
if 'SH' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,J_error_SH, label='SH J')
    plt.legend()

# %%
# compute the error in the target
from pymor.discretizers.builtin.cg import (L2ProductP1, L2ProductQ1, InterpolationOperator)
from pymor.discretizers.builtin.grids.referenceelements import square
from pymor.discretizers.builtin.grids.boundaryinfos import EmptyBoundaryInfo
if data['grid'].reference_element is square:
    L2_OP = L2ProductQ1
else:
    L2_OP = L2ProductP1
if mu_d is None:
    if 'SH' in optimization_methods or 'All' in optimization_methods:
        empty_bi = EmptyBoundaryInfo(data['grid'])
        u_d = InterpolationOperator(data['grid'], ConstantFunction(u_d,2)).as_vector()
        diff= u.to_numpy()-u_d.to_numpy()
        diff_= opt_fom.solution_space.from_numpy(diff)
        Restricted_L2_OP = L2_OP(data['grid'], empty_bi, dirichlet_clear_rows=False, coefficient_function=domain_of_interest)
        print("{}".format(Restricted_L2_OP.apply2(diff_,diff_)[0][0]))
        print("{}".format(Restricted_L2_OP.apply2(diff_,diff_)[0][0]/Restricted_L2_OP.apply2(u_d,u_d)))
# Out:
# 0.6493595693967626
# [[0.01717392]]

# %% [markdown]
# # TR-RB approaches

# %%
import time
from pdeopt.model import build_initial_basis
from pdeopt.reductor import QuadraticPdeoptStationaryCoerciveReductor
from pdeopt.TR import TR_algorithm, TR_algorithm_with_optional_enrichment

from pymor.parameters.functionals import MinThetaParameterFunctional
ce = MinThetaParameterFunctional(opt_fom.primal_model.operator.coefficients, mu_bar)

set_defaults({'pymor.operators.constructions.induced_norm.raise_negative': False})
set_defaults({'pymor.operators.constructions.induced_norm.tol': 1e-20})

# %% [markdown]
# ## Newton Method

# %% [markdown]
# ### NCD-corrected

# %% [markdown]
# #### Lagrange Basis (Method 4)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_4' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver,
                 'JFE_start': J_start} # This is not cheating because the quantity to compute this are accessible when preparing pdeopt_reductor
                                       # so the computational time to compute this is already

    extension_params = {'Enlarge_radius': True, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_4, times_4, Js_4, FOC_4, data_4 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space,
                                                TR_parameters, extension_params)
    
    times_full_4_actual, J_error_4_actual, mu_error_4_actual, FOC_4_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_4, Js_4, times_4, tictoc, FOC_4)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.11539923532130057, 0.0538889347741837], heaters: [54.96624778787091, 43.53223926182769, 42.0367802087489, 33.03348210038741, 20.46486340378425, 61.92709663506637, 29.965467367452312], walls: [0.045012045632715006, 0.07158503745769712, 0.06468565707077795]}
# Starting value of the cost: 41.966877846296256
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09524204] 3.1782555396522616
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# k: 0 - j 2 - Cost Functional: 22.270254725350753 - mu: {doors: [0.05, 0.2], heaters: [52.91259288635629, 41.55332534645153, 41.119753457620995, 32.20442829672642, 19.874430018543432, 61.20110581479147, 26.28049997089903], walls: [0.025, 0.1, 0.1]}
# enlarging the TR radius to 0.2
# computing the fom gradient since the model was enriched
# First order critical condition: 3.1825520946472574
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.1943585] 2.0249367923005206
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# k: 1 - j 4 - Cost Functional: 13.08139375150057 - mu: {doors: [0.05, 0.05], heaters: [48.92769424030702, 38.809120815563325, 40.482481920989834, 32.58858635254805, 23.192297681578985, 63.511625926744415, 23.45510643248242], walls: [0.025, 0.1, 0.1]}
# enlarging the TR radius to 0.4
# computing the fom gradient since the model was enriched
# First order critical condition: 2.024604505678397
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 59.49580, because p_k is not a descent direction
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.38217199] 0.915592818451386
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# k: 2 - j 5 - Cost Functional: 7.6331524135212305 - mu: {doors: [0.05, 0.05], heaters: [40.303033835463495, 33.58506880881684, 42.970192012800396, 37.823913230662875, 31.92252129171787, 59.64016185846768, 22.43341133255896], walls: [0.038517826124769394, 0.1, 0.1]}
# enlarging the TR radius to 0.8
# computing the fom gradient since the model was enriched
# First order critical condition: 0.9158998896811957
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.14332, because p_k is not a descent direction
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.007891106281597735, J_diff = 0.00024848183637534777, FOC = 6.153480596427404e-15
# relative differences mu 0.007891106281597735 and J 0.00024848183637534777
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# k: 3 - j 5 - Cost Functional: 5.814646110884832 - mu: {doors: [0.05, 0.05], heaters: [22.401458748995324, 23.392071429883035, 48.6149062938533, 49.15917018639789, 52.36347154476558, 54.26225829640781, 23.635902744583525], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 1.6
# computing the fom gradient since the model was enriched
# First order critical condition: 0.020891146821527585
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.003022788829927568, J_diff = 5.548032703348002e-05, FOC = 3.552713678800501e-15
# relative differences mu 0.003022788829927568 and J 5.548032703348002e-05
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# k: 4 - j 2 - Cost Functional: 5.813965804238466 - mu: {doors: [0.05, 0.05], heaters: [22.378989436959813, 23.404820465137288, 48.719887066197465, 49.386808744879104, 52.368676086242004, 54.07047055615802, 23.525068131314026], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 3.2
# computing the fom gradient since the model was enriched
# First order critical condition: 7.295264993813597e-05
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0004672635939954096, J_diff = 1.2802388216712866e-07, FOC = 5.724397161122838e-11
# relative differences mu 0.0004672635939954096 and J 1.2802388216712866e-07
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 5.813965063172313 - mu: {doors: [0.05, 0.05], heaters: [22.382428592016353, 23.396471441536573, 48.703581275000545, 49.37445044591556, 52.36196585372992, 54.116229713730526, 23.52380579691182], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 6.4
# computing the fom gradient since the model was enriched
# First order critical condition: 8.680207727530294e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 9.545549036887032e-06, J_diff = 4.96151606793496e-11, FOC = 8.086979178731568e-12
# relative differences mu 9.545549036887032e-06 and J 4.96151606793496e-11
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 8 and 8
# k: 6 - j 2 - Cost Functional: 5.813965062884122 - mu: {doors: [0.05, 0.05], heaters: [22.382549259730723, 23.39650237436582, 48.70348036312782, 49.3742289158462, 52.36272703879146, 54.11556051013893, 23.523801043528795], walls: [0.025, 0.025, 0.025]}
# enlarging the TR radius to 12.8
# computing the fom gradient since the model was enriched
# First order critical condition: 7.0306209433021186e-09
# *******************************
#
#
# Stopping criteria fulfilled: FOC condition: 7.0306209433021186e-09
# Computing only the initial FOC

# %%
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,mu_error_4_actual)

# %% [markdown]
# #### Lagrange Basis with optional enrichment (Method 4.a)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver,
                 'tau_g': tau_g, 'tau_grad': tau_grad, 'beta_3': beta_3,
                 'minimum_radius': minimum_radius, 'maximum_radius': maximum_radius, 
                 'JFE_start': J_start}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_4bis, times_4bis, Js_4bis, FOC_4bis, data_4bis = TR_algorithm_with_optional_enrichment(opt_rom, pdeopt_reductor, parameter_space,
                                                TR_parameters, extension_params)
    
    times_full_4bis_actual, J_error_4bis_actual, mu_error_4bis_actual, FOC_4bis_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_4bis, Js_4bis, times_4bis, tictoc, FOC_4bis)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.11539923532130057, 0.0538889347741837], heaters: [54.96624778787091, 43.53223926182769, 42.0367802087489, 33.03348210038741, 20.46486340378425, 61.92709663506637, 29.965467367452312], walls: [0.045012045632715006, 0.07158503745769712, 0.06468565707077795]}
# Starting value of the cost: 41.966877846296256
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09524204] 3.1782555396522616
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# enlarging the TR radius to 0.2
# k: 0 - j 2 - Cost Functional: 22.270254738882613 - mu: {doors: [0.05, 0.2], heaters: [52.91259288635629, 41.55332534645153, 41.119753457620995, 32.20442829672642, 19.874430018543432, 61.20110581479147, 26.28049997089903], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 3.1825520946472574
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.1943585] 2.0249367923005206
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# enlarging the TR radius to 0.4
# k: 1 - j 4 - Cost Functional: 13.081393759705861 - mu: {doors: [0.05, 0.05], heaters: [48.92769424030702, 38.809120815563325, 40.482481920989834, 32.58858635254805, 23.192297681578985, 63.511625926744415, 23.45510643248242], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 2.024604505678397
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 59.49580, because p_k is not a descent direction
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.38217199] 0.915592818451386
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# enlarging the TR radius to 0.8
# k: 2 - j 5 - Cost Functional: 7.633152416852454 - mu: {doors: [0.05, 0.05], heaters: [40.303033835463495, 33.58506880881684, 42.970192012800396, 37.823913230662875, 31.92252129171787, 59.64016185846768, 22.43341133255896], walls: [0.038517826124769394, 0.1, 0.1]}
# First order critical condition: 0.9158998896811957
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.14332, because p_k is not a descent direction
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.007891106281597735, J_diff = 0.00024848183637534777, FOC = 6.153480596427404e-15
# relative differences mu 0.007891106281597735 and J 0.00024848183637534777
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# enlarging the TR radius to 1.6
# k: 3 - j 5 - Cost Functional: 5.814646110466356 - mu: {doors: [0.05, 0.05], heaters: [22.401458748995324, 23.392071429883035, 48.6149062938533, 49.15917018639789, 52.36347154476558, 54.26225829640781, 23.635902744583525], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.020891146821527585
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.003022788829927568, J_diff = 5.548032703348002e-05, FOC = 3.552713678800501e-15
# relative differences mu 0.003022788829927568 and J 5.548032703348002e-05
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# enlarging the TR radius to 3.2
# k: 4 - j 2 - Cost Functional: 5.813965803741667 - mu: {doors: [0.05, 0.05], heaters: [22.378989436959813, 23.404820465137288, 48.719887066197465, 49.386808744879104, 52.368676086242004, 54.07047055615802, 23.525068131314026], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 7.295264993813597e-05
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0004672635939954096, J_diff = 1.2802388216712866e-07, FOC = 5.724397161122838e-11
# relative differences mu 0.0004672635939954096 and J 1.2802388216712866e-07
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# enlarging the TR radius to 6.4
# k: 5 - j 2 - Cost Functional: 5.81396506267356 - mu: {doors: [0.05, 0.05], heaters: [22.382428592016353, 23.396471441536573, 48.703581275000545, 49.37445044591556, 52.36196585372992, 54.116229713730526, 23.52380579691182], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 8.680207727530294e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 9.545549036887032e-06, J_diff = 4.96151606793496e-11, FOC = 8.086979178731568e-12
# relative differences mu 9.545549036887032e-06 and J 4.96151606793496e-11
#
# Stopping criteria fulfilled: FOC condition: 7.0306209433021186e-09
# k: 6 - j 2 - Cost Functional: 5.813965062882804 - mu: {doors: [0.05, 0.05], heaters: [22.382549259730723, 23.39650237436582, 48.70348036312782, 49.3742289158462, 52.36272703879146, 54.11556051013893, 23.523801043528795], walls: [0.025, 0.025, 0.025]}
# Computing only the initial FOC

# %%
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,mu_error_4bis_actual)

# %% [markdown]
# #### Directional Taylor Basis (Method 5)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_5' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'AdaptiveTaylor_Newton',  'iterative_solver': iterative_solver,
                 'JFE_start': J_start}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_5, times_5, Js_5, FOC_5, data_5 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_5_actual, J_error_5_actual, mu_error_5_actual, FOC_5_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_5, Js_5, times_5, tictoc, FOC_5)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.11539923532130057, 0.0538889347741837], heaters: [54.96624778787091, 43.53223926182769, 42.0367802087489, 33.03348210038741, 20.46486340378425, 61.92709663506637, 29.965467367452312], walls: [0.045012045632715006, 0.07158503745769712, 0.06468565707077795]}
# Starting value of the cost: 41.966877846296256
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09524204] 3.1782555396522616
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 3 and 3
# k: 0 - j 2 - Cost Functional: 22.27025472535155 - mu: {doors: [0.05, 0.2], heaters: [52.91259288635629, 41.55332534645153, 41.119753457620995, 32.20442829672642, 19.874430018543432, 61.20110581479147, 26.28049997089903], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 3.1825520946472574
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.0962291] 1.9711189715465351
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 5 and 5
# k: 1 - j 3 - Cost Functional: 12.768223231958643 - mu: {doors: [0.05, 0.05], heaters: [49.03987697204167, 38.790307972228966, 40.58793708655445, 32.48130934694588, 22.624578588005136, 61.81957734813305, 23.84036224168774], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.9715116599684117
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09947599] 1.03961144117321
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 7 and 7
# k: 2 - j 4 - Cost Functional: 8.170015271481432 - mu: {doors: [0.05, 0.05], heaters: [43.0210326934224, 35.06804862747055, 42.13082842183149, 35.907054413008005, 28.460306189719848, 59.39262354488435, 22.645345263192116], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.039877763268579
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.51785, because p_k is not a descent direction
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.0959815] 0.07341271862446766
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Length of Bases are 9 and 9
# k: 3 - j 4 - Cost Functional: 5.836670158109607 - mu: {doors: [0.05, 0.05], heaters: [22.638726789150393, 23.603753201151612, 48.90049810899126, 49.41800640162501, 52.14606844018905, 53.31643382765916, 23.78494067904642], walls: [0.025, 0.07296144367968788, 0.07958028702162848]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.07340913097858819
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.008648643576108752, J_diff = 0.0009672977913386257, FOC = 3.552713678800501e-15
# relative differences mu 0.008648643576108752 and J 0.0009672977913386257
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 11 and 11
# k: 4 - j 2 - Cost Functional: 5.813966076890102 - mu: {doors: [0.05, 0.05], heaters: [22.387347307371765, 23.40289751496988, 48.69264508031655, 49.33628765393002, 52.380708735427746, 54.110315440661275, 23.529681504112173], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.0005406357911281037
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0004110587990662973, J_diff = 1.3342409966689763e-07, FOC = 1.1783018260144473e-14
# relative differences mu 0.0004110587990662973 and J 1.3342409966689763e-07
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 13 and 13
# k: 5 - j 2 - Cost Functional: 5.8139650629755035 - mu: {doors: [0.05, 0.05], heaters: [22.38246465313564, 23.39647032016665, 48.703551212094, 49.37444712198843, 52.362276674692424, 54.11584017140809, 23.52382553728438], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 4.551850817397623e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 5.288703286142092e-06, J_diff = 1.5544285110491992e-11, FOC = 3.145199180679665e-12
# relative differences mu 5.288703286142092e-06 and J 1.5544285110491992e-11
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Length of Bases are 15 and 15
# k: 6 - j 2 - Cost Functional: 5.813965062885959 - mu: {doors: [0.05, 0.05], heaters: [22.38254746126955, 23.396504447709653, 48.70348441040342, 49.37422825695095, 52.362723186090726, 54.11556166932927, 23.523800744034574], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.3123723394328988e-09
# *******************************
#
#
# Stopping criteria fulfilled: FOC condition: 1.3123723394328988e-09
# Computing only the initial FOC

# %%
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,mu_error_5_actual)

# %% [markdown]
# #### Directional Taylor Basis with optional enrichment (Method 5.a)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu,  'iterative_solver': iterative_solver,
                 'tau_g': tau_g, 'tau_grad': tau_grad, 'beta_3': beta_3,
                 'minimum_radius': minimum_radius, 'maximum_radius': maximum_radius, 
                 'opt_method': 'AdaptiveTaylor_Newton',  
                 'JFE_start': J_start} 

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_5bis, times_5bis, Js_5bis, FOC_5bis, data_5bis = TR_algorithm_with_optional_enrichment(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_5bis_actual, J_error_5bis_actual, mu_error_5bis_actual, FOC_5bis_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_5bis, Js_5bis, times_5bis, tictoc, FOC_5bis)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.11539923532130057, 0.0538889347741837], heaters: [54.96624778787091, 43.53223926182769, 42.0367802087489, 33.03348210038741, 20.46486340378425, 61.92709663506637, 29.965467367452312], walls: [0.045012045632715006, 0.07158503745769712, 0.06468565707077795]}
# Starting value of the cost: 41.966877846296256
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.09524204] 3.1782555396522616
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 3 and 3
# enlarging the TR radius to 0.2
# k: 0 - j 2 - Cost Functional: 22.270254738882613 - mu: {doors: [0.05, 0.2], heaters: [52.91259288635629, 41.55332534645153, 41.119753457620995, 32.20442829672642, 19.874430018543432, 61.20110581479147, 26.28049997089903], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 3.1825520946472574
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.1991039] 1.9095215036857127
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 5 and 5
# enlarging the TR radius to 0.4
# k: 1 - j 4 - Cost Functional: 12.316881138433473 - mu: {doors: [0.05, 0.05], heaters: [47.853885345465315, 38.10492657579919, 40.62082113861751, 32.87278360338512, 24.121813348306336, 62.392702450117305, 23.810012796641985], walls: [0.025, 0.1, 0.1]}
# First order critical condition: 1.9097488411888457
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# boundary criterium of the TR satisfied, so stopping the sub-problem [0.39051726] 0.7621606110572348
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 7 and 7
# enlarging the TR radius to 0.8
# k: 2 - j 6 - Cost Functional: 7.07031373752443 - mu: {doors: [0.05, 0.05], heaters: [37.232872475493444, 31.800098973211785, 43.9732084834439, 39.81958281457622, 35.35185480002516, 57.897184483109676, 22.936915884028142], walls: [0.04183418118437841, 0.1, 0.1]}
# First order critical condition: 0.7629215859599433
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Using CG for the linear system
# Using CG for the linear system
# CG truncated at iteration: 1 with residual: 0.23204, because p_k is not a descent direction
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.011757364577955003, J_diff = 0.001121261024987685, FOC = 0.0
# relative differences mu 0.011757364577955003 and J 0.001121261024987685
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 9 and 9
# enlarging the TR radius to 1.6
# k: 3 - j 5 - Cost Functional: 5.813968663911055 - mu: {doors: [0.05, 0.05], heaters: [22.40651669763833, 23.39841225983574, 48.635093848788884, 49.38941283240582, 52.30906112535737, 54.159635124472004, 23.529737145160613], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 0.0006054667379153914
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 0.0009348216091955229, J_diff = 5.710400187565506e-07, FOC = 3.552713678800501e-15
# relative differences mu 0.0009348216091955229 and J 5.710400187565506e-07
# Sufficient decrease condition fulfilled
# Enriching the RB model
# building simple coercive dual reductor...
# Length of Bases are 11 and 11
# enlarging the TR radius to 3.2
# k: 4 - j 2 - Cost Functional: 5.81396506313331 - mu: {doors: [0.05, 0.05], heaters: [22.38271776211441, 23.396633658148918, 48.703658883283715, 49.374445491717175, 52.36365829046043, 54.114291987613235, 23.52367135978076], walls: [0.025, 0.025, 0.025]}
# First order critical condition: 2.5708663118352817e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the Newton method
# Using CG for the linear system
# Subproblem converged: mu_diff = 1.4893609357496705e-05, J_diff = 1.2894032771891387e-10, FOC = 2.276281599044783e-11
# relative differences mu 1.4893609357496705e-05 and J 1.2894032771891387e-10
#
# Stopping criteria fulfilled: FOC condition: 2.1355631330593033e-08
# k: 5 - j 2 - Cost Functional: 5.813965062874503 - mu: {doors: [0.05, 0.05], heaters: [22.382542933897827, 23.396504983049194, 48.7034946695077, 49.37422237445123, 52.36270942892293, 54.1155733046455, 23.52380192601091], walls: [0.025, 0.025, 0.025]}
# Computing only the initial FOC

# %%
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,mu_error_5bis_actual)

# %% [markdown]
# ### Aggregated

# %% [markdown]
# #### excluding directional sensitivities (Method 6) -- (b)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)

if 'Method_6' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                unique_basis=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'NewtonMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_6, times_6, Js_6, FOC_6, data_6 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_6_actual, J_error_6_actual, mu_error_6_actual, FOC_6_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_6, Js_6, times_6, tictoc, FOC_6)

# %%
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual, mu_error_6_actual)

# %% [markdown]
# #### including directional sensitivities (Method 7) -- (d)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)

if 'Method_7' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                prepare_for_hessian=True,
                                                unique_basis=True,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'estimate_tolerance': estimate_tolerance, 
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'AdaptiveTaylor_Newton',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}
    
    mus_7, times_7, Js_7, FOC_7, data_7 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_7_actual, J_error_7_actual, mu_error_7_actual, FOC_7_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_7, Js_7, times_7, tictoc, FOC_7)

# %%
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,mu_error_7_actual)

# %% [markdown]
# ## NCD corrected BFGS Method (KMSOV'20)

# %%
tic = time.time()
params = [mu]

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=True)
opt_fom = opt_fom.with_(adjoint_approach=True)

if 'Method_8' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(
        opt_fom, params, build_sensitivities=False)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                RBbasis, dual_RBbasis, 
                                                opt_product=opt_fom.opt_product,
                                                coercivity_estimator=ce,
                                                reductor_type=reductor_type, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()

    tictoc = time.time() - tic

    TR_parameters = {'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'BFGSMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_8, times_8, Js_8, FOC_8, data_8 = TR_algorithm(opt_rom, pdeopt_reductor, parameter_space, 
                                                TR_parameters, extension_params)
    
    times_full_8_actual, J_error_8_actual, mu_error_8_actual, FOC_8_actual = compute_errors(
        opt_fom, parameter_space, J_start, J_opt, mu, mu_opt_as_array, mus_8, Js_8, times_8, tictoc, FOC_8)
# Out:
# Starting with two bases. Primal and dual have length 1 and 1
# building simple coercive primal reductor...
# building simple coercive dual reductor...
# starting parameter {doors: [0.11539923532130057, 0.0538889347741837], heaters: [54.96624778787091, 43.53223926182769, 42.0367802087489, 33.03348210038741, 20.46486340378425, 61.92709663506637, 29.965467367452312], walls: [0.045012045632715006, 0.07158503745769712, 0.06468565707077795]}
# Starting value of the cost: 41.966877846296256
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 2 and 2
# k: 0 - j 2 - Cost Functional: 21.737285765306638 - mu: {doors: [0.05, 0.2], heaters: [53.10734439803361, 41.62191342498838, 41.070287341838, 32.058974791624905, 19.434062522648404, 60.845528228296075, 26.193122846474573], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 3.123063797608154
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 3 and 3
# k: 1 - j 4 - Cost Functional: 7.989951340264227 - mu: {doors: [0.05, 0.05], heaters: [50.41586114836032, 38.883184280350804, 39.704322012615904, 30.685237094532503, 17.98768701303739, 59.30931099147224, 20.84865936437371], walls: [0.025, 0.1, 0.1]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.708431578558242
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -0.0008473346838916837
# Reset direction to - gradient
# Curvature condition: -1.3302665275451674e-06
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 4 and 4
# k: 2 - j 7 - Cost Functional: 7.220662326963451 - mu: {doors: [0.05, 0.05], heaters: [49.41820338032463, 37.955264051218904, 39.306355669352435, 30.301282108754375, 17.608475997803822, 58.83497274484987, 19.28633909853699], walls: [0.04154124157054375, 0.026670561907615457, 0.07193444609118438]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.09443629868061962
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 5 and 5
# k: 3 - j 4 - Cost Functional: 7.053901465105827 - mu: {doors: [0.05, 0.05], heaters: [47.3783838147722, 36.90860845481079, 39.549234975127625, 30.737440486091934, 18.367389282516235, 58.80487896379862, 20.159230552999073], walls: [0.1, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.07664348455107309
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -0.00044298864488439524
# Reset direction to - gradient
# Curvature condition: -0.0052508437046900405
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 6 and 6
# k: 4 - j 12 - Cost Functional: 6.796707985195258 - mu: {doors: [0.05, 0.05], heaters: [43.49066469671128, 34.9693089446482, 40.11977281780877, 31.714220497842422, 20.027992942604904, 58.81569540523603, 21.898119499283805], walls: [0.08783323728032255, 0.042630020751094136, 0.025561095128607846]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.12830693094805776
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.05 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.025 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.0125 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.00625 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.003125 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Maximum iteration for Armijo rule reached
# Curvature condition: 0.0
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 2 - Cost Functional: 6.773680086453123 - mu: {doors: [0.05, 0.05], heaters: [43.495338266208776, 34.994984157263474, 40.149350743255276, 31.748656788974902, 20.071534589558176, 58.84134867234529, 22.001597857010292], walls: [0.1, 0.025, 0.025]}
# Shrinking the TR radius to: 0.0015625 because Jcp 6.77365558148572 and J_kp1 6.773680086453123
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -0.0037656238538035986
# Reset direction to - gradient
# Curvature condition: -7.0008897450789e-05
# Reset direction to - gradient
# Curvature condition: -2.1867237205055053e-05
# Reset direction to - gradient
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 7 and 7
# k: 5 - j 3 - Cost Functional: 6.787543750681646 - mu: {doors: [0.05, 0.05], heaters: [43.49081230787606, 34.97017387982304, 40.12077724327476, 31.715390924908327, 20.029474573365494, 58.81656594313893, 21.901631031312245], walls: [0.08881151895968568, 0.027581973035435692, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.11504521104788515
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 8 and 8
# k: 6 - j 12 - Cost Functional: 6.4420998989921525 - mu: {doors: [0.05, 0.05], heaters: [37.317465071720534, 32.15908965946024, 41.52451917787955, 33.92573207269523, 23.598995420085615, 59.12190759960063, 25.25027836811974], walls: [0.0998626409239931, 0.02743189831003513, 0.02526841349940151]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.17279636375648294
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 9 and 9
# k: 7 - j 5 - Cost Functional: 6.40092727457305 - mu: {doors: [0.05, 0.05], heaters: [37.09781945559578, 31.972788970855742, 41.467670083775964, 33.880982855067636, 23.57066474432633, 59.036777501202785, 24.96465500496932], walls: [0.06784689256345974, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.042811555798284426
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 10 and 10
# k: 8 - j 5 - Cost Functional: 6.394436070078722 - mu: {doors: [0.05, 0.05], heaters: [36.95735138781982, 31.88677640325372, 41.479054323254765, 33.91081165934479, 23.63047507413375, 59.01997505587256, 24.917808414465146], walls: [0.025846338584215985, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.03610084361643717
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 11 and 11
# k: 9 - j 8 - Cost Functional: 6.13814471113885 - mu: {doors: [0.05, 0.05], heaters: [30.127988631602562, 28.640943818544145, 43.40496300011368, 37.05745283448184, 28.816317927043453, 59.312612128277145, 26.48485026998057], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.11580199835670048
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 12 and 12
# k: 10 - j 26 - Cost Functional: 6.0093205992236705 - mu: {doors: [0.05, 0.05], heaters: [27.671684232394725, 27.53840727136631, 44.95205478191883, 39.53255275786122, 32.836613313143914, 59.616762272825625, 26.431928433140946], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.021038433176099703
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 13 and 13
# k: 11 - j 45 - Cost Functional: 5.836286145019107 - mu: {doors: [0.05, 0.05], heaters: [21.50881997755355, 23.969970441258194, 49.50821063241164, 47.315079261369995, 45.92852681007517, 59.679979477785956, 24.250082242099207], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.021084378173380262
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# boundary criterium of the TR satisfied, so stopping the sub-problem solver
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 14 and 14
# k: 12 - j 124 - Cost Functional: 5.818436509181515 - mu: {doors: [0.05, 0.05], heaters: [23.404453596952827, 23.287095927314212, 49.30308891357285, 48.87000366687845, 50.16907284500619, 56.48964594740853, 22.978628441475706], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 0.005577609454505613
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# relative differences mu 1.4568924652308358e-07 and J 3.2600353658973696e-13
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 15 and 15
# k: 13 - j 400 - Cost Functional: 5.813963760843196 - mu: {doors: [0.05, 0.05], heaters: [22.381817849210528, 23.397688225049258, 48.72040468264845, 49.39140505963679, 52.3468842804398, 54.100017075958824, 23.52369767138715], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.7012987018837876e-05
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -2.6000054249227684e-33
# Reset direction to - gradient
# Subproblem converged: FOC = 6.147613085353281e-07, mu_diff = 3.232147927624148e-17, J_diff = 0.0
# relative differences mu 3.232147927624148e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 16 and 16
# k: 14 - j 150 - Cost Functional: 5.8139650708438 - mu: {doors: [0.05, 0.05], heaters: [22.38242421670187, 23.396376577878957, 48.700655173286, 49.371489989676135, 52.36535497035147, 54.118473626989534, 23.523776212921415], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 2.9022510173375564e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -7.69207862189388e-31
# Reset direction to - gradient
# Subproblem converged: FOC = 1.0124321885783508e-06, mu_diff = 1.408864314391505e-16, J_diff = 0.0
# relative differences mu 1.408864314391505e-16 and J 0.0
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 17 and 17
# k: 15 - j 64 - Cost Functional: 5.813965063045803 - mu: {doors: [0.05, 0.05], heaters: [22.382778949986147, 23.39675567078847, 48.703277817561435, 49.37402011552808, 52.362736101963606, 54.11547929926455, 23.5236924250358], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.0116692956771786e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 1.0370616565428476e-06, mu_diff = 2.16819638222422e-16, J_diff = 0.0
# relative differences mu 2.16819638222422e-16 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 18 and 18
# k: 16 - j 5 - Cost Functional: 5.813965063043744 - mu: {doors: [0.05, 0.05], heaters: [22.382777037667264, 23.396753551884046, 48.70327921391336, 49.37402152825233, 52.36273681727095, 54.11548038621308, 23.523698048808527], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 1.0378911141821242e-06
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 9.549511976980331e-07, mu_diff = 1.8283837700528632e-16, J_diff = 0.0
# relative differences mu 1.8283837700528632e-16 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 19 and 19
# k: 17 - j 6 - Cost Functional: 5.813965063039948 - mu: {doors: [0.05, 0.05], heaters: [22.38277305716352, 23.39674928759387, 48.7032791244919, 49.37402143196637, 52.36273602531684, 54.115479859715514, 23.52369780306138], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 9.542263987829388e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 2.2283889344412008e-07, mu_diff = 3.8520449414433107e-10, J_diff = 0.0
# relative differences mu 3.8520449414433107e-10 and J 0.0
# checked sufficient condition, starting enrichment
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 20 and 20
# k: 18 - j 31 - Cost Functional: 5.81396506290967 - mu: {doors: [0.05, 0.05], heaters: [22.382585996498715, 23.396546675346734, 48.70332159379418, 49.37406421066616, 52.36273338025136, 54.11549793841344, 23.523861743693594], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 2.2248472668452042e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.51612635251708e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 21 and 21
# k: 19 - j 7 - Cost Functional: 5.813965062909329 - mu: {doors: [0.05, 0.05], heaters: [22.38258670072214, 23.396547282156035, 48.70332812402231, 49.374070815258335, 52.36273589876126, 54.11550241097332, 23.523859217623095], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528992194168279e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.516034723455098e-07, mu_diff = 2.364348053616401e-13, J_diff = 0.0
# relative differences mu 2.364348053616401e-13 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 22 and 22
# k: 20 - j 1 - Cost Functional: 5.813965062909563 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712892, 23.39654728214629, 48.703328124020985, 49.374070815256964, 52.36273589875702, 54.115502410970045, 23.523859217601586], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909903442627e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.516028507786695e-07, mu_diff = 3.232156155076181e-17, J_diff = 0.0
# relative differences mu 3.232156155076181e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 22 and 22
# k: 21 - j 1 - Cost Functional: 5.813965062909563 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712892, 23.39654728214629, 48.703328124020985, 49.374070815256964, 52.36273589875702, 54.115502410970045, 23.523859217601583], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909903442627e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: -2.3490326790448067e-31
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516028507786695e-07, mu_diff = 3.232156155076181e-17, J_diff = 3.0553276811596173e-16
# relative differences mu 3.232156155076181e-17 and J 3.0553276811596173e-16
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 22 and 22
# k: 22 - j 1 - Cost Functional: 5.813965062909562 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712892, 23.39654728214629, 48.703328124020985, 49.374070815256964, 52.36273589875702, 54.115502410970045, 23.52385921760158], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909874041649e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.516028182835067e-07, mu_diff = 9.350935549364542e-16, J_diff = 0.0
# relative differences mu 9.350935549364542e-16 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 23 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 24 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 25 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 26 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 27 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 28 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 29 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 23
# k: 30 - j 1 - Cost Functional: 5.813965062907748 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516075899263492e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 31 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.523859217601494], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 3.232156155076182e-17, J_diff = 0.0
# relative differences mu 3.232156155076182e-17 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 32 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 33 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 34 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 35 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 36 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 37 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 24
# k: 38 - j 1 - Cost Functional: 5.813965062908707 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516051136537292e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 39 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 40 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 41 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 42 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 43 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 44 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 45 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 46 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 47 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 25
# k: 48 - j 1 - Cost Functional: 5.813965062904877 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.516149440465902e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 23 and 26
# k: 49 - j 1 - Cost Functional: 5.813965062904641 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712856, 23.39654728214625, 48.70332812402098, 49.37407081525696, 52.36273589875701, 54.11550241097003, 23.52385921760149], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528909680317949e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Subproblem converged: FOC = 8.516155533498159e-07, mu_diff = 1.8380712513533584e-15, J_diff = 0.0
# relative differences mu 1.8380712513533584e-15 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 50 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 51 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 52 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 53 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 54 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 27
# k: 55 - j 1 - Cost Functional: 5.81396506290449 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.5161589160559e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 56 - j 1 - Cost Functional: 5.813965062912306 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.515956751036171e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 57 - j 1 - Cost Functional: 5.813965062912306 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.515956751036171e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 58 - j 1 - Cost Functional: 5.813965062912306 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
# ___ starting subproblem
# Computing the approximate Cauchy point and then start the BFGS method
# Curvature condition: 0.0
# Reset direction to - gradient
# Subproblem converged: FOC = 8.515956751036171e-07, mu_diff = 0.0, J_diff = 0.0
# relative differences mu 0.0 and J 0.0
# enriching to check the sufficient decrease condition
# building simple coercive dual reductor...
# Enrichment completed... length of Bases are 24 and 28
# k: 59 - j 1 - Cost Functional: 5.813965062912306 - mu: {doors: [0.05, 0.05], heaters: [22.382586700712785, 23.396547282146177, 48.70332812402097, 49.37407081525694, 52.36273589875697, 54.11550241097, 23.523859217601323], walls: [0.025, 0.025, 0.025]}
# computing the fom gradient since the model was enriched
# First order critical condition: 8.528908958906097e-07
# *******************************
#
#  WARNING: Maximum number of iteration for the TR algorithm reached
# Computing only the initial FOC

# %%
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,mu_error_8_actual)

# %% [markdown]
# ## Qian-Grepl-Method

# %%
#Qian-Grepl

# make sure to use the correct config
opt_fom = opt_fom.with_(use_corrected_functional=False)
opt_fom = opt_fom.with_(adjoint_approach=False)
tic = time.time()
params = [mu]

if 'Method_9' in optimization_methods or 'All' in optimization_methods:

    RBbasis, dual_RBbasis = build_initial_basis(opt_fom, params)

    pdeopt_reductor = QuadraticPdeoptStationaryCoerciveReductor(opt_fom, 
                                                                RBbasis, dual_RBbasis, 
                                                                opt_product=opt_fom.opt_product, 
                                                                prepare_for_hessian=False,
                                                                prepare_for_gradient_estimate=True,
                                                                coercivity_estimator=ce, mu_bar=mu_bar)

    opt_rom = pdeopt_reductor.reduce()
    tictoc = time.time() - tic
    
    TR_parameters = {'Qian-Grepl': True,
                 'Qian-Grepl_subproblem': Qian_Grepl_subproblem, 'beta': beta,
                 'safety_tolerance': safety_tol,
                 'radius': radius, 'FOC_tolerance': FOC_tolerance, 
                 'sub_tolerance': sub_tolerance,
                 'max_iterations': max_it, 'max_iterations_subproblem': max_it_sub, 
                 'max_iterations_armijo': max_it_arm,
                 'initial_step_armijo': init_step_armijo, 
                 'armijo_alpha': armijo_alpha, 
                 'epsilon_i': epsilon_i, 
                 'control_mu': control_mu,
                 'starting_parameter': mu, 
                 'opt_method': 'BFGSMethod',  'iterative_solver': iterative_solver}

    extension_params = {'Enlarge_radius': False, 'timings': True, 
                        'opt_fom': opt_fom, 'return_data_dict': True}

    mus_9, times_9, Js_9, FOC_9, data_9 = TR_algorithm(
        opt_rom, pdeopt_reductor, parameter_space, TR_parameters, extension_params)

    times_full_9_actual, J_error_9_actual, FOC_9_actual, mu_error_9_actual = compute_actual_errors(
        opt_fom, parameter_space, J_start, J_opt, mus_9, times_9, tictoc, mu, mu_opt_as_array)

# %%
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,J_error_9_actual)

# %% [markdown]
# # Results

# %%
print(mu_opt)
u = opt_fom.solve(mu_opt)
opt_fom.visualize(u)
# Out:
# {doors: [0.05, 0.05], heaters: [22.38254711947, 23.39650455721, 48.70348426512, 49.37422778852, 52.36272251326, 54.11556305764, 23.52380079299], walls: [0.025, 0.025, 0.025]}
# Output()

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### J error

# %%
timings_figure = plt.figure()
if 'SH' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,J_error_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,J_error_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,J_error_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,J_error_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag. optional')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,J_error_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay. optional')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual,J_error_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,J_error_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,J_error_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,J_error_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('True optimization error of the output functional')
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Plot FOC

# %%
timings_figure = plt.figure()

if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH, FOC_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual, FOC_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual, FOC_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual, FOC_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag.')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual, FOC_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay.')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual, FOC_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual, FOC_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual, FOC_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual, FOC_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('First-order critical condition')
# plt.xlim([-1,30])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Plot Mu error

# %%
if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_SH,mu_error_SH,'o-', label='SH Method')
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4_actual,mu_error_4_actual,'o-', label='4. Newton NCD-corrected Lag.')
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5_actual,mu_error_5_actual,'o-', label='5. Newton NCD-corrected Dir.Tay.')
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_4bis_actual,mu_error_4bis_actual,'o-', label='4.a Newton NCD-corrected Lag.')
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_5bis_actual,mu_error_5bis_actual,'o-', label='5.a Newton NCD-corrected Dir.Tay.')
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_6_actual,mu_error_6_actual,'o-', label='6. Newton Aggr.')
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_7_actual,mu_error_7_actual,'o-', label='7. Newton Aggr. Dir.Tay')
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_8_actual,mu_error_8_actual,'o-', label='8. NCD-corrected BFGS')
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    plt.semilogy(times_full_9_actual,mu_error_9_actual,'o-', label='9. Qian-Grepl')

plt.xlabel('time in seconds [s]')
plt.ylabel('Mu error')
#plt.xlim([-1,100])
plt.grid()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#timings_figure.savefig('compare_FEM_TR', format='pdf', bbox_inches="tight")

# %% [markdown]
# ### Save the data

# %%
#save data
from pdeopt.tools import save_data

directory = f'results/Starter{seed}'

if 'SH' in optimization_methods or 'FOM' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_SH, J_error_SH, 1, mu_error=mu_error_SH, FOC=FOC_SH)
if 'Method_4' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_4_actual, J_error_4_actual, 4, mu_error=mu_error_4_actual, FOC=FOC_4_actual, additional_data=data_4)
if 'Method_5' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_5_actual, J_error_5_actual, 5, mu_error=mu_error_5_actual, FOC=FOC_5_actual, additional_data=data_5)
if 'Method_4_optional' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_4bis_actual, J_error_4bis_actual, 2, mu_error=mu_error_4bis_actual, FOC=FOC_4bis_actual, additional_data=data_4bis)
if 'Method_5_optional' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_5bis_actual, J_error_5bis_actual, 3, mu_error=mu_error_5bis_actual, FOC=FOC_5bis_actual, additional_data=data_5bis)
if 'Method_6' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_6_actual, J_error_6_actual, 6, mu_error=mu_error_6_actual, FOC=FOC_6_actual, additional_data=data_6)
if 'Method_7' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_7_actual, J_error_7_actual, 7, mu_error=mu_error_7_actual, FOC=FOC_7_actual, additional_data=data_7)
if 'Method_8' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_8_actual, J_error_8_actual, 8, mu_error=mu_error_8_actual, FOC=FOC_8_actual, additional_data=data_8)
if 'Method_9' in optimization_methods or 'All' in optimization_methods:
    save_data(directory, times_full_9_actual, J_error_9_actual, 9, mu_error=mu_error_9_actual, FOC=FOC_9_actual, additional_data=data_9)
